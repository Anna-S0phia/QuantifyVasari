# %% [markdown]
# ## The Programming Historian
#
# # Understanding and Using Common Similarity Measures for Text Analysis
#
# #### This Jupyter notebook is based on John R. Ladd, "Understanding and Using Common Similarity Measures for Text Analysis," The Programming Historian 9 (2020), https://doi.org/10.46430/phen0089.

# %%
import os
import glob
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from scipy.spatial.distance import pdist, squareform

# %%
# create a list of file names
#filenames = glob.glob('data/Cosine/*.txt') # Cosine: every author in a single .txt file, plus "other" (9 in total)
#filenames = glob.glob('data/Cosine2/*.txt') # Cosine plus every biography in a single file named 'unkown_artistname.txt'
filenames = glob.glob('data/Cosine3/*.txt') # Cosine2, but Vasari and VCopy in one single file

# create a list of file keys 
filekeys = [f.split('/')[-1].split('.')[0] for f in filenames]

# Create a CountVectorizer instance with the parameters you need
vectorizer = CountVectorizer(input="filename", max_features=1000, max_df=0.7)

# vectorize the documents in the list of filenames to create the wordcounts
wordcounts = vectorizer.fit_transform(filenames).toarray()

# %% [markdown]
# # Cosine similarity

# %%
# make one big datafram with all the distances
cosine_distances = pd.DataFrame(squareform(pdist(wordcounts, metric='cosine')), index=filekeys, columns=filekeys)
cosine_distances.drop('other', 1).drop('other',0)
# Out:
#                                                     Minerbetti  \
# Minerbetti                                            0.000000
# unkown_Pesello-e-Francesco-Peselli                    0.937885
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...    0.906162
# unkown_Cosimo-Rosselli                                0.947169
# unkown_Andrea-Pisano                                  0.909371
# ...                                                        ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli    0.910866
# unkown_Stefano-e-Ugolino                              0.891347
# unkown_Perino-del-Vaga                                0.870870
# unkown_Tommaso-Fiorentino-detto-Giottino              0.910391
# Giambullari                                           0.288782
#
#                                                     unkown_Pesello-e-Francesco-Peselli  \
# Minerbetti                                                                    0.937885
# unkown_Pesello-e-Francesco-Peselli                                            0.000000
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                            0.847712
# unkown_Cosimo-Rosselli                                                        0.764926
# unkown_Andrea-Pisano                                                          0.758686
# ...                                                                                ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                            0.815657
# unkown_Stefano-e-Ugolino                                                      0.805895
# unkown_Perino-del-Vaga                                                        0.776782
# unkown_Tommaso-Fiorentino-detto-Giottino                                      0.804624
# Giambullari                                                                   0.921121
#
#                                                     unkown_Pulidoro-da-Caravaggio-e-Maturino-Fiorentino  \
# Minerbetti                                                                                   0.906162
# unkown_Pesello-e-Francesco-Peselli                                                           0.847712
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                           0.000000
# unkown_Cosimo-Rosselli                                                                       0.820358
# unkown_Andrea-Pisano                                                                         0.744969
# ...                                                                                               ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                           0.738942
# unkown_Stefano-e-Ugolino                                                                     0.786399
# unkown_Perino-del-Vaga                                                                       0.643657
# unkown_Tommaso-Fiorentino-detto-Giottino                                                     0.764297
# Giambullari                                                                                  0.897592
#
#                                                     unkown_Cosimo-Rosselli  \
# Minerbetti                                                        0.947169
# unkown_Pesello-e-Francesco-Peselli                                0.764926
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                0.820358
# unkown_Cosimo-Rosselli                                            0.000000
# unkown_Andrea-Pisano                                              0.847499
# ...                                                                    ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                0.739551
# unkown_Stefano-e-Ugolino                                          0.731893
# unkown_Perino-del-Vaga                                            0.768825
# unkown_Tommaso-Fiorentino-detto-Giottino                          0.711913
# Giambullari                                                       0.943116
#
#                                                     unkown_Andrea-Pisano  \
# Minerbetti                                                      0.909371
# unkown_Pesello-e-Francesco-Peselli                              0.758686
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...              0.744969
# unkown_Cosimo-Rosselli                                          0.847499
# unkown_Andrea-Pisano                                            0.000000
# ...                                                                  ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli              0.786064
# unkown_Stefano-e-Ugolino                                        0.734316
# unkown_Perino-del-Vaga                                          0.711590
# unkown_Tommaso-Fiorentino-detto-Giottino                        0.697853
# Giambullari                                                     0.899845
#
#                                                     unkown_Giovan-Francesco-detto-il-Fattore-e-Pellegrino-da-Modana  \
# Minerbetti                                                                                   0.947427
# unkown_Pesello-e-Francesco-Peselli                                                           0.853956
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                           0.762968
# unkown_Cosimo-Rosselli                                                                       0.793508
# unkown_Andrea-Pisano                                                                         0.864086
# ...                                                                                               ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                           0.620313
# unkown_Stefano-e-Ugolino                                                                     0.785885
# unkown_Perino-del-Vaga                                                                       0.618413
# unkown_Tommaso-Fiorentino-detto-Giottino                                                     0.778086
# Giambullari                                                                                  0.954720
#
#                                                     unkown_Lazzaro-Vasari  \
# Minerbetti                                                       0.683737
# unkown_Pesello-e-Francesco-Peselli                               0.752021
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...               0.800752
# unkown_Cosimo-Rosselli                                           0.792603
# unkown_Andrea-Pisano                                             0.787199
# ...                                                                   ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli               0.702540
# unkown_Stefano-e-Ugolino                                         0.750145
# unkown_Perino-del-Vaga                                           0.746380
# unkown_Tommaso-Fiorentino-detto-Giottino                         0.691882
# Giambullari                                                      0.694687
#
#                                                     unkown_Margaritone  \
# Minerbetti                                                    0.862213
# unkown_Pesello-e-Francesco-Peselli                            0.783096
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...            0.787596
# unkown_Cosimo-Rosselli                                        0.811116
# unkown_Andrea-Pisano                                          0.733546
# ...                                                                ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli            0.781325
# unkown_Stefano-e-Ugolino                                      0.769120
# unkown_Perino-del-Vaga                                        0.769340
# unkown_Tommaso-Fiorentino-detto-Giottino                      0.662528
# Giambullari                                                   0.887643
#
#                                                     unkown_Simone-Mosca  \
# Minerbetti                                                     0.882098
# unkown_Pesello-e-Francesco-Peselli                             0.799383
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...             0.766415
# unkown_Cosimo-Rosselli                                         0.763430
# unkown_Andrea-Pisano                                           0.617294
# ...                                                                 ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli             0.647650
# unkown_Stefano-e-Ugolino                                       0.759882
# unkown_Perino-del-Vaga                                         0.630630
# unkown_Tommaso-Fiorentino-detto-Giottino                       0.732002
# Giambullari                                                    0.898836
#
#                                                     unkown_Iacopo-di-Casentino  \
# Minerbetti                                                            0.943773
# unkown_Pesello-e-Francesco-Peselli                                    0.823015
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                    0.824409
# unkown_Cosimo-Rosselli                                                0.731423
# unkown_Andrea-Pisano                                                  0.798240
# ...                                                                        ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                    0.747060
# unkown_Stefano-e-Ugolino                                              0.781073
# unkown_Perino-del-Vaga                                                0.832264
# unkown_Tommaso-Fiorentino-detto-Giottino                              0.614806
# Giambullari                                                           0.955790
#
#                                                     ...  \
# Minerbetti                                          ...
# unkown_Pesello-e-Francesco-Peselli                  ...
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  ...
# unkown_Cosimo-Rosselli                              ...
# unkown_Andrea-Pisano                                ...
# ...                                                 ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  ...
# unkown_Stefano-e-Ugolino                            ...
# unkown_Perino-del-Vaga                              ...
# unkown_Tommaso-Fiorentino-detto-Giottino            ...
# Giambullari                                         ...
#
#                                                     unkown_Benvenuto-Garofalo-e-Girolamo-da-Carpi-e-altri-lombardi  \
# Minerbetti                                                                                   0.761848
# unkown_Pesello-e-Francesco-Peselli                                                           0.779603
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                           0.673929
# unkown_Cosimo-Rosselli                                                                       0.718190
# unkown_Andrea-Pisano                                                                         0.645036
# ...                                                                                               ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                           0.478277
# unkown_Stefano-e-Ugolino                                                                     0.639111
# unkown_Perino-del-Vaga                                                                       0.586599
# unkown_Tommaso-Fiorentino-detto-Giottino                                                     0.606039
# Giambullari                                                                                  0.767394
#
#                                                     unkown_Giulio-Romano  \
# Minerbetti                                                      0.930914
# unkown_Pesello-e-Francesco-Peselli                              0.890405
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...              0.770628
# unkown_Cosimo-Rosselli                                          0.863666
# unkown_Andrea-Pisano                                            0.813696
# ...                                                                  ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli              0.713645
# unkown_Stefano-e-Ugolino                                        0.826864
# unkown_Perino-del-Vaga                                          0.682474
# unkown_Tommaso-Fiorentino-detto-Giottino                        0.808347
# Giambullari                                                     0.923079
#
#                                                     unkown_Andrea-dal-Castagno-di-Mugello-e-Dominico-Viniziano  \
# Minerbetti                                                                                   0.937144
# unkown_Pesello-e-Francesco-Peselli                                                           0.740917
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                           0.793174
# unkown_Cosimo-Rosselli                                                                       0.758296
# unkown_Andrea-Pisano                                                                         0.439473
# ...                                                                                               ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                           0.657126
# unkown_Stefano-e-Ugolino                                                                     0.717389
# unkown_Perino-del-Vaga                                                                       0.717991
# unkown_Tommaso-Fiorentino-detto-Giottino                                                     0.744560
# Giambullari                                                                                  0.928833
#
#                                                     unkown_Sebastian-Viniziano-frate-del-Piombo  \
# Minerbetti                                                                             0.872896
# unkown_Pesello-e-Francesco-Peselli                                                     0.830888
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                     0.723898
# unkown_Cosimo-Rosselli                                                                 0.782834
# unkown_Andrea-Pisano                                                                   0.765510
# ...                                                                                         ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                     0.577383
# unkown_Stefano-e-Ugolino                                                               0.746979
# unkown_Perino-del-Vaga                                                                 0.600833
# unkown_Tommaso-Fiorentino-detto-Giottino                                               0.760812
# Giambullari                                                                            0.864241
#
#                                                     unkown_Giorgio-Vasari  \
# Minerbetti                                                       0.393716
# unkown_Pesello-e-Francesco-Peselli                               0.884712
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...               0.781679
# unkown_Cosimo-Rosselli                                           0.815419
# unkown_Andrea-Pisano                                             0.774268
# ...                                                                   ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli               0.704622
# unkown_Stefano-e-Ugolino                                         0.768611
# unkown_Perino-del-Vaga                                           0.711609
# unkown_Tommaso-Fiorentino-detto-Giottino                         0.771813
# Giambullari                                                      0.457802
#
#                                                     unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  \
# Minerbetti                                                                                   0.910866
# unkown_Pesello-e-Francesco-Peselli                                                           0.815657
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                           0.738942
# unkown_Cosimo-Rosselli                                                                       0.739551
# unkown_Andrea-Pisano                                                                         0.786064
# ...                                                                                               ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                           0.000000
# unkown_Stefano-e-Ugolino                                                                     0.673612
# unkown_Perino-del-Vaga                                                                       0.640054
# unkown_Tommaso-Fiorentino-detto-Giottino                                                     0.649514
# Giambullari                                                                                  0.915510
#
#                                                     unkown_Stefano-e-Ugolino  \
# Minerbetti                                                          0.891347
# unkown_Pesello-e-Francesco-Peselli                                  0.805895
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                  0.786399
# unkown_Cosimo-Rosselli                                              0.731893
# unkown_Andrea-Pisano                                                0.734316
# ...                                                                      ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                  0.673612
# unkown_Stefano-e-Ugolino                                            0.000000
# unkown_Perino-del-Vaga                                              0.722195
# unkown_Tommaso-Fiorentino-detto-Giottino                            0.515369
# Giambullari                                                         0.889447
#
#                                                     unkown_Perino-del-Vaga  \
# Minerbetti                                                        0.870870
# unkown_Pesello-e-Francesco-Peselli                                0.776782
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                0.643657
# unkown_Cosimo-Rosselli                                            0.768825
# unkown_Andrea-Pisano                                              0.711590
# ...                                                                    ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                0.640054
# unkown_Stefano-e-Ugolino                                          0.722195
# unkown_Perino-del-Vaga                                            0.000000
# unkown_Tommaso-Fiorentino-detto-Giottino                          0.744462
# Giambullari                                                       0.854887
#
#                                                     unkown_Tommaso-Fiorentino-detto-Giottino  \
# Minerbetti                                                                          0.910391
# unkown_Pesello-e-Francesco-Peselli                                                  0.804624
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...                                  0.764297
# unkown_Cosimo-Rosselli                                                              0.711913
# unkown_Andrea-Pisano                                                                0.697853
# ...                                                                                      ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli                                  0.649514
# unkown_Stefano-e-Ugolino                                                            0.515369
# unkown_Perino-del-Vaga                                                              0.744462
# unkown_Tommaso-Fiorentino-detto-Giottino                                            0.000000
# Giambullari                                                                         0.924728
#
#                                                     Giambullari
# Minerbetti                                             0.288782
# unkown_Pesello-e-Francesco-Peselli                     0.921121
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...     0.897592
# unkown_Cosimo-Rosselli                                 0.943116
# unkown_Andrea-Pisano                                   0.899845
# ...                                                         ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli     0.915510
# unkown_Stefano-e-Ugolino                               0.889447
# unkown_Perino-del-Vaga                                 0.854887
# unkown_Tommaso-Fiorentino-detto-Giottino               0.924728
# Giambullari                                            0.000000
#
# [176 rows x 176 columns]

# %%
#cosine_distances.drop('other',0).sort_values(by = ['Vasariplus'])['Vasariplus'][:20]



cosine_distances.drop('other',0).drop('other',1).sort_values(by = ['Vasari'])                #['Vasari'][:20]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-2332091bea57> in <module>
#       3
#       4
# ----> 5 cosine_distances.drop('other',0).drop('other',1).sort_values(by = ['Vasari'])                #['Vasari'][:20]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'Vasari'

# %%
# make new dataframe only with the author candidate columns

cosine_distances2 = pd.DataFrame()                         # comment out depending on which folder was chosen!


cosine_distances2['Vasari'] = cosine_distances['Vasariplus']   # Vasari and copies together or
#cosine_distances2['Vasari'] = cosine_distances['Vasari']         # Vasari and copies split
#cosine_distances2['VasariC'] = cosine_distances['Vcopy']

cosine_distances2['Minerbetti'] = cosine_distances['Minerbetti']
cosine_distances2['Ghiberti'] = cosine_distances['Ghiberti']
cosine_distances2['Borghini'] = cosine_distances['Borghini']
cosine_distances2['Bartoli'] = cosine_distances['Bartoli']
cosine_distances2['Sanga'] = cosine_distances['Sanga']
cosine_distances2['Giambullari'] = cosine_distances['Giambullari']

#cosine_distances2.drop('other')#.drop('unkown')
cosine_distances2
# Out:
#                                                       Vasari  Minerbetti  \
# Minerbetti                                          0.268090    0.000000
# unkown_Pesello-e-Francesco-Peselli                  0.922825    0.937885
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  0.871934    0.906162
# unkown_Cosimo-Rosselli                              0.936107    0.947169
# unkown_Andrea-Pisano                                0.872480    0.909371
# ...                                                      ...         ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  0.871368    0.910866
# unkown_Stefano-e-Ugolino                            0.844073    0.891347
# unkown_Perino-del-Vaga                              0.819733    0.870870
# unkown_Tommaso-Fiorentino-detto-Giottino            0.889407    0.910391
# Giambullari                                         0.339773    0.288782
#
#                                                     Ghiberti  Borghini  \
# Minerbetti                                          0.768238  0.197637
# unkown_Pesello-e-Francesco-Peselli                  0.961876  0.930589
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  0.924489  0.863298
# unkown_Cosimo-Rosselli                              0.967797  0.932236
# unkown_Andrea-Pisano                                0.926984  0.868171
# ...                                                      ...       ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  0.941805  0.853703
# unkown_Stefano-e-Ugolino                            0.941158  0.840815
# unkown_Perino-del-Vaga                              0.937129  0.812193
# unkown_Tommaso-Fiorentino-detto-Giottino            0.939892  0.897734
# Giambullari                                         0.944741  0.204360
#
#                                                      Bartoli     Sanga  \
# Minerbetti                                          0.230707  0.484728
# unkown_Pesello-e-Francesco-Peselli                  0.912532  0.925048
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  0.871101  0.925096
# unkown_Cosimo-Rosselli                              0.867683  0.956386
# unkown_Andrea-Pisano                                0.878459  0.939373
# ...                                                      ...       ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  0.868761  0.925126
# unkown_Stefano-e-Ugolino                            0.869462  0.917184
# unkown_Perino-del-Vaga                              0.839988  0.904458
# unkown_Tommaso-Fiorentino-detto-Giottino            0.888480  0.931625
# Giambullari                                         0.291263  0.578698
#
#                                                     Giambullari
# Minerbetti                                             0.288782
# unkown_Pesello-e-Francesco-Peselli                     0.921121
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...     0.897592
# unkown_Cosimo-Rosselli                                 0.943116
# unkown_Andrea-Pisano                                   0.899845
# ...                                                         ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli     0.915510
# unkown_Stefano-e-Ugolino                               0.889447
# unkown_Perino-del-Vaga                                 0.854887
# unkown_Tommaso-Fiorentino-detto-Giottino               0.924728
# Giambullari                                            0.000000
#
# [177 rows x 7 columns]

# %%
cosine_distances2.loc['unkown_Vite-Introduction']
# Out:
# Vasari         0.671876
# Minerbetti     0.759471
# Ghiberti       0.819443
# Borghini       0.670485
# Bartoli        0.698431
# Sanga          0.803080
# Giambullari    0.737087
# Name: unkown_Vite-Introduction, dtype: float64

# %%
#cosine_distances = pd.DataFrame(squareform(pdist(wordcounts, metric='cosine')), index=filekeys, columns=filekeys)
topVasari_cosine = cosine_distances.nsmallest(20, 'Vasari')['Vasari']
#print(topVasari_cosine[1:])

# %%
#have a look at first results
cosine_distances2.loc['unkown_Francia-Bigio']['Vasari'], cosine_distances.loc['unkown_Francia-Bigio']['Borghini']
# Out:
# (0.9054131305373565, 0.9094371821045837)

# %% [markdown]
# (0.9056021423714086, 0.9099339737093348)

# %%
cosine_distances2
# Out:
#                                                       Vasari  Minerbetti  \
# Minerbetti                                          0.268090    0.000000
# unkown_Pesello-e-Francesco-Peselli                  0.922825    0.937885
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  0.871934    0.906162
# unkown_Cosimo-Rosselli                              0.936107    0.947169
# unkown_Andrea-Pisano                                0.872480    0.909371
# ...                                                      ...         ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  0.871368    0.910866
# unkown_Stefano-e-Ugolino                            0.844073    0.891347
# unkown_Perino-del-Vaga                              0.819733    0.870870
# unkown_Tommaso-Fiorentino-detto-Giottino            0.889407    0.910391
# Giambullari                                         0.339773    0.288782
#
#                                                     Ghiberti  Borghini  \
# Minerbetti                                          0.768238  0.197637
# unkown_Pesello-e-Francesco-Peselli                  0.961876  0.930589
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  0.924489  0.863298
# unkown_Cosimo-Rosselli                              0.967797  0.932236
# unkown_Andrea-Pisano                                0.926984  0.868171
# ...                                                      ...       ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  0.941805  0.853703
# unkown_Stefano-e-Ugolino                            0.941158  0.840815
# unkown_Perino-del-Vaga                              0.937129  0.812193
# unkown_Tommaso-Fiorentino-detto-Giottino            0.939892  0.897734
# Giambullari                                         0.944741  0.204360
#
#                                                      Bartoli     Sanga  \
# Minerbetti                                          0.230707  0.484728
# unkown_Pesello-e-Francesco-Peselli                  0.912532  0.925048
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...  0.871101  0.925096
# unkown_Cosimo-Rosselli                              0.867683  0.956386
# unkown_Andrea-Pisano                                0.878459  0.939373
# ...                                                      ...       ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli  0.868761  0.925126
# unkown_Stefano-e-Ugolino                            0.869462  0.917184
# unkown_Perino-del-Vaga                              0.839988  0.904458
# unkown_Tommaso-Fiorentino-detto-Giottino            0.888480  0.931625
# Giambullari                                         0.291263  0.578698
#
#                                                     Giambullari
# Minerbetti                                             0.288782
# unkown_Pesello-e-Francesco-Peselli                     0.921121
# unkown_Pulidoro-da-Caravaggio-e-Maturino-Fioren...     0.897592
# unkown_Cosimo-Rosselli                                 0.943116
# unkown_Andrea-Pisano                                   0.899845
# ...                                                         ...
# unkown_Giovannantonio-detto-il-Soddoma-da-Verzelli     0.915510
# unkown_Stefano-e-Ugolino                               0.889447
# unkown_Perino-del-Vaga                                 0.854887
# unkown_Tommaso-Fiorentino-detto-Giottino               0.924728
# Giambullari                                            0.000000
#
# [177 rows x 7 columns]

# %%
# Biographies written by Vasari, argued by Charles Hope

x = cosine_distances2.loc['unkown_Giorgio-Vasari']
y = cosine_distances2.loc['unkown_Spinello-Aretino']
z = cosine_distances2.loc['unkown_Niccolò-Aretino']
d = cosine_distances2.loc['unkown_Benvenuto-Garofalo-e-Girolamo-da-Carpi-e-altri-lombardi']
f = cosine_distances2.loc['unkown_Taddeo-Gaddi']

temp = pd.DataFrame()
temp['Giorgio Vasari'] = x
temp['Spinello Aretino'] = y
temp['Niccolò Aretino'] = z
temp['Garofalo & Girolamo'] = d
temp['Taddeo Gaddi'] = f


#temp['Francia'] = q

temp
#temp.loc['Vasari'],
# Out:
#              Giorgio Vasari  Spinello Aretino  Niccolò Aretino  \
# Vasari             0.368305          0.895824          0.894559
# Minerbetti         0.393716          0.903461          0.899600
# Ghiberti           0.922314          0.919966          0.940599
# Borghini           0.330595          0.901230          0.893514
# Bartoli            0.384883          0.906465          0.904549
# Sanga              0.646803          0.943909          0.949016
# Giambullari        0.457802          0.923857          0.902747
#
#              Garofalo & Girolamo  Taddeo Gaddi
# Vasari                  0.684761      0.914213
# Minerbetti              0.761848      0.938799
# Ghiberti                0.907216      0.938157
# Borghini                0.698738      0.915288
# Bartoli                 0.727574      0.921279
# Sanga                   0.795127      0.943848
# Giambullari             0.767394      0.933810

# %%
#temp.loc['Vcopy'],

# %%
#temp.loc['Borghini'],

# %%
#temp.sort_values(by = 'Garofalo & Girolamo')[:40]

# %%
# Biorgaphies NOT written by Vasari (Charles Hope, 2014)


x = cosine_distances2.loc['unkown_Lionardo-da-Vinci']
y = cosine_distances2.loc['unkown_Sebastian-Viniziano-frate-del-Piombo']
z = cosine_distances2.loc['unkown_Perino-del-Vaga']
a = cosine_distances2.loc['unkown_Giulio-Romano']
b = cosine_distances2.loc['unkown_Antonio-da-San-Gallo']
c = cosine_distances2.loc['unkown_Raffaello-dUrbino']
d = cosine_distances2.loc['unkown_Bramante-da-Urbino']
q = cosine_distances2.loc['unkown_Francia-Bigio']


temp = pd.DataFrame()
temp['Lionardo da Vinci'] = x
temp['Sebastian del Piombo'] = y
temp['Perino del Vaga'] = z
temp['Giulio Romano'] = a
temp['Antonio da San Gallo'] = b
temp['Raffaello'] = c
temp['Bramante'] = d
temp['Francia Bigio'] = q


temp
# Out:
#              Lionardo da Vinci  Sebastian del Piombo  Perino del Vaga  \
# Vasari                0.838227              0.831960         0.819733
# Minerbetti            0.894706              0.872896         0.870870
# Ghiberti              0.926913              0.925713         0.937129
# Borghini              0.833627              0.823101         0.812193
# Bartoli               0.846568              0.843865         0.839988
# Sanga                 0.893628              0.880148         0.904458
# Giambullari           0.893186              0.864241         0.854887
#
#              Giulio Romano  Antonio da San Gallo  Raffaello  Bramante  \
# Vasari            0.887650              0.887772   0.832026  0.816323
# Minerbetti        0.930914              0.939161   0.886069  0.885258
# Ghiberti          0.948187              0.945193   0.898223  0.912918
# Borghini          0.895242              0.912065   0.822368  0.833868
# Bartoli           0.899286              0.913919   0.833984  0.850107
# Sanga             0.923969              0.919343   0.896218  0.877811
# Giambullari       0.923079              0.931137   0.870369  0.862951
#
#              Francia Bigio
# Vasari            0.906122
# Minerbetti        0.938437
# Ghiberti          0.952901
# Borghini          0.909321
# Bartoli           0.913987
# Sanga             0.942674
# Giambullari       0.941179

# %% [markdown]
# # Save and open dataframe as csv

# %%
filename = 'cosine_distance.csv'
#cosine_distances.to_csv(filename, index = False, header=True)
#cosine_distances = pd.read_csv(filename)
