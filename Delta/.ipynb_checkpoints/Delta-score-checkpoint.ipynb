# %% [markdown]
# ## The Programming Historian
# # Introduction to stylometry with Python
#
# #### This jupyter notebook is based on François Dominic Laramée, "Introduction to stylometry with Python," The Programming Historian 7 (2018), https://doi.org/10.46430/phen0078.

# %%
import os
import nltk
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Functions to read the formatted files into dictionaries to work with

# %%
# A function that compiles all of the text files  
# associated with a single author into a single string

def read_files_into_string(datapath, filenames):
    strings = []
    for file in filenames:
        with open(datapath + '/' + file) as f:
            strings.append(f.read())
    return '\n'.join(strings)

# %%
# A function that extracts all author names (author_file.txt format)
# and but filenames to author key into a dict

def get_filenames_per_author_into_dict(datapath):
    list_of_files = os.listdir(datapath)
    store = list()
    for i in list_of_files:
        store.append(i.split('_')[0])
    authors = list(set(store))
    storage = {}
    count = 0
    for a in authors:
        store2 = list()
        for f in list_of_files:
            if f.startswith(a):
                store2.append(f)
            else:
                continue
        storage[authors[count]] = store2
        count += 1       
    return storage

# %%
# put every author into a single string in a dict
# (author_file.txt format in a single folder)

def get_single_string_per_author_into_dict(datapath):
    x = get_filenames_per_author_into_dict(datapath)
    authors = list(x.keys())
    strings_by_author = {}
    
    for author in authors:
        strings_by_author[author] = read_files_into_string(datapath, x[author])

    return strings_by_author

# %%
# transform authors' corpora into lists of word tokens
# (author_file.txt format in a single folder)

def get_tokens_by_author(datapath):
    # call get single string per author function to process data first
    strings = get_single_string_per_author_into_dict(datapath)
    authors = strings.keys()
    
    # storage variables
    length_distribution = []
    sorted_length = []
    author_tokens = {}
    author_length_distributions = {}
    
    # tokenize strings
    for author in authors:
        tokens = nltk.word_tokenize(strings[author], language = 'italian')
    
    # Filter out punctuation
        author_tokens[author] = ([token for token in tokens if any(c.isalpha() for c in token)])

    # Get a distribution of token lengths
        token_lengths = [len(token) for token in author_tokens[author]]
        author_length_distributions[author] = nltk.FreqDist(token_lengths)
        
    #author_length_distributions[author].plot(15,title=author)
        sorted_length.append((dict(sorted((dict(author_length_distributions[author])).items()))))
        length_distribution.append(author_length_distributions[author])
    
    return author_tokens

# %% [markdown]
# # Load data as list of tokens per author in a dict

# %%
datapath = '../data/formatted/formatted_letters_lives_Ghiberti/'
tokens_by_author = get_tokens_by_author(datapath)

# %%
tokens_by_author.keys()
# Out:
# dict_keys(['VasariC', 'Borghini', 'Ghiberti', 'unkown', 'Sanga', 'Vasari', 'other', 'Bartoli', 'Giambullari', 'Minerbetti'])

# %% [markdown]
# ## make .txt file for each author for general purpose

# %%
# write .txt file (string per author, not tokens)
datapath = '../data/formatted/formatted_letters_lives_Ghiberti/'

string_per_author = get_single_string_per_author_into_dict(datapath)
authors = string_per_author.keys()
for author in authors:
    text = string_per_author[author]
    filename = '../data/formatted/'+ author + '.txt'
    output = open(filename, "wt")
    output.write(text)
    output.close()

# %% [markdown]
# # Stylometrie: Mendenhall’s Characteristic Curves of Composition
# #### Compare the different authors' corpora by wordlength

# %%
plot_path = '../data/plots/Mendenhall/'

# %%
# check who is in the dict
tokens_by_author.keys()
# Out:
# dict_keys(['VasariC', 'Borghini', 'Ghiberti', 'unkown', 'Sanga', 'Vasari', 'other', 'Bartoli', 'Giambullari', 'Minerbetti'])

# %%
# make selection of plotted authors
authors = ['Giambullari', 'Minerbetti', 'Ghiberti', 'Vasari', 'Bartoli', 'VasariC', 'Borghini', 'Sanga']

# %%
# Transform the authors' corpora into lists of word tokens
storage_length = []
sorted_storage = []
lives_by_author_length_distributions = {}
#authors = list(tokens_by_author.keys()) # comment this out, when you make a individual list of authors above

for author in authors:

    # Get a distribution of token lengths
    token_lengths = [len(token) for token in tokens_by_author[author]]
    lives_by_author_length_distributions[author] = nltk.FreqDist(token_lengths)
    
    # sort by length and converted to dict    
    x = ((dict(sorted((dict(lives_by_author_length_distributions[author])).items()))))
    sorted_storage.append(x)
    
    # save plot
    filename = plot_path + author + '_Mendenhall.png'
    
    # plot Mendenhall one after another
    fig = plt.figure(figsize = (20,10))
    plt.gcf().subplots_adjust(bottom=0.15) # to avoid x-ticks cut-off
    lives_by_author_length_distributions[author].plot(14,title=author)
    plt.xlim([1.5, 12])
    plt.ylim([0.06, 0.23])
    plt.show()
    fig.savefig(filename, bbox_inches = "tight") #

    # make all in one relative plot
    #plt.figure()
    plt.plot((x.keys()),np.array(list(x.values())) / sum(x.values()))
    plt.xlim([1.5, 8]) # zoom in plot
    plt.ylim([0.06, 0.23])
    
    # check how many authors you have included
    plt.legend([authors[0],authors[1],authors[2],authors[3],authors[4],authors[5], authors[6], authors[7]]) #, authors[8]
    #plt.show()
    #fig.savefig(filename, bbox_inches = "tight")    

    #plt.imsave(filename, lives_by_author_length_distributions[author])

    storage_length.append(lives_by_author_length_distributions[author])     # save distribution in storage_length list
    
#plt.show()    
len(storage_length)
# Out:
# 8

# %%
filename = './data/plots/Mendenhall/test.jpg'

# %%
# make selection of plotted authors
authors = [ 'Minerbetti', 'Ghiberti', 'Vasari', 'Bartoli', 'Vasaric', 'Borghini', 'Sanga']
for author in authors:
    
    filename = plot_path + author + '_Mendenhall.jpg'
    
    # plot Mendenhall one after another
    fig = plt.figure(dpi=300) #figsize = (15,10)
    #plt.gcf().subplots_adjust(bottom=0.15) # to avoid x-ticks cut-off
    lives_by_author_length_distributions[author].plot(12,title=author )
    #plt.xlim([1.5, 12])
    #plt.ylim([0.06, 0.23])
    #plt.show()
    
    #fig.savefig('test.jpg')
    #plt.xlabel('Wordlength')
    #plt.ylabel('Wordcount')
    fig.savefig(filename) #, bbox_inches = "tight"

# %%
lives_by_author_length_distributions.keys()
# Out:
# dict_keys(['Giambullari', 'Minerbetti', 'Ghiberti', 'Vasari', 'Bartoli', 'VasariC', 'Borghini', 'Sanga'])

# %%
#WORKING VERSION LIKE ABOVE BUT OTHER FILENAMES AND FUNCTIONS IMPLEMENTED


storage_length = []
sorted_storage = []
lives_by_author_length_distributions = {}
authors = tokens_by_author.keys()

for author in authors:

    # Get a distribution of token lengths
    token_lengths = [len(token) for token in tokens_by_author[author]]
    lives_by_author_length_distributions[author] = nltk.FreqDist(token_lengths)
    
    # sort by length and converted to dict    
    x = ((dict(sorted((dict(lives_by_author_length_distributions[author])).items()))))
    sorted_storage.append(x)
    
    # plot Mendenhall one after another
    #lives_by_author_length_distributions[author].plot(15,title=author)

    # make all in one relative plot
    plt.plot((x.keys()),np.array(list(x.values())) / sum(x.values()))
    plt.xlim([1.5, 6.5])
    plt.ylim([0.06, 0.23])
    #plt.legend([authors[0],authors[1],authors[2],authors[3],authors[4],authors[5], authors[6], authors[7], authors[8]])
    
    # save plot
    filename = plot_path + author + '_Mendenhall.png'
    #plt.imsave(filename, lives_by_author_length_distributions[author])

    storage_length.append(lives_by_author_length_distributions[author])     # save distribution in storage_length list

    
#plt.show()    
len(storage_length)
# Out:
# 10

# %% [markdown]
# # Second Stylometric Test: Kilgariff’s Chi-Squared Method
#
# ### the smaller the value, the more similar

# %%
# load data into dict

datapath = './Delta_data/'

tokens_by_author = get_tokens_by_author(datapath)

# %%
#tokens_by_author.keys()

# %%
tokens_by_author['VasariPlusC'] = tokens_by_author['VasariC'] + tokens_by_author['Vasari']
len(tokens_by_author['Vasari']), len(tokens_by_author['VasariC']),len(tokens_by_author['VasariPlusC']), (len(tokens_by_author['Vasari']) + len(tokens_by_author['VasariC']))
# Out:
# (219006, 36942, 255948, 255948)

# %%
# transfer to variable! named in the whole notebook

lives_by_author_tokens = tokens_by_author

# %%
# Who are the authors we are analyzing?
authorsV = ("VasariPlusC", 'Borghini', 'Minerbetti', 'Borghini', 'Bartoli', 'Giambullari', 'Sanga', 'Ghiberti')

# how many common words are we taking into account? 
x = 100

# Lowercase the tokens so that the same word, capitalized or not,
# counts as one word
for author in authorsV:
    lives_by_author_tokens[author] = (
        [token.lower() for token in lives_by_author_tokens[author]])
lives_by_author_tokens["unkown"] = (
    [token.lower() for token in lives_by_author_tokens["unkown"]])

# Calculate chisquared for each of the two candidate authors
for author in authorsV:

    # First, build a joint corpus and identify the X most frequent words in it
    joint_corpus = (lives_by_author_tokens[author] +
                    lives_by_author_tokens["unkown"])
    joint_freq_dist = nltk.FreqDist(joint_corpus)
    most_common = list(joint_freq_dist.most_common(x))

    # What proportion of the joint corpus is made up
    # of the candidate author's tokens?
    author_share = (len(lives_by_author_tokens[author])
                    / len(joint_corpus))

    # Now, let's look at the 500 most common words in the candidate
    # author's corpus and compare the number of times they can be observed
    # to what would be expected if the author's papers
    # and the Disputed papers were both random samples from the same distribution.
    chisquared = 0
    for word,joint_count in most_common:

        # How often do we really see this common word?
        author_count = lives_by_author_tokens[author].count(word)
        disputed_count = lives_by_author_tokens["unkown"].count(word)

        # How often should we see it?
        expected_author_count = joint_count * author_share
        expected_disputed_count = joint_count * (1-author_share)

        # Add the word's contribution to the chi-squared statistic
        chisquared += ((author_count-expected_author_count) *
                       (author_count-expected_author_count) /
                       expected_author_count)

        chisquared += ((disputed_count-expected_disputed_count) *
                       (disputed_count-expected_disputed_count)
                       / expected_disputed_count)

    print("The Chi-squared statistic for candidate", author, "is", round(chisquared,3))
# Out:
# The Chi-squared statistic for candidate VasariPlusC is 30786.395
# The Chi-squared statistic for candidate Borghini is 21537.382
# The Chi-squared statistic for candidate Minerbetti is 2632.894
# The Chi-squared statistic for candidate Borghini is 21537.382
# The Chi-squared statistic for candidate Bartoli is 3487.838
# The Chi-squared statistic for candidate Giambullari is 702.004
# The Chi-squared statistic for candidate Sanga is 4568.807
# The Chi-squared statistic for candidate Ghiberti is 27353.874

# %% [markdown]
# # Third Stylometric Test: John Burrows’ Delta Method

# %%
# load data into dict

datapath = './Delta_data/'

tokens_by_author = get_tokens_by_author(datapath)

# make one list of tokens für Vasari and the copies
tokens_by_author['VasariPlusC'] = tokens_by_author['VasariC'] + tokens_by_author['Vasari']

# %%
# transfer into variable

lives_by_author_tokens = tokens_by_author

# %%
# Feature Selection

x = 100    # SET THE NUMBER OF MOST COMMON WORDS!

# Who are we dealing with this time?
authorsV = ('Giambullari', 'Minerbetti', 'VasariPlusC', 'Bartoli', 'Ghiberti', 'Borghini', 'Sanga')#
#authorsV = lives_by_author_tokens.keys()
# Convert papers to lowercase to count all tokens of the same word together
# regardless of case

for author in authorsV:
    lives_by_author_tokens[author] = (
        [tok.lower() for tok in lives_by_author_tokens[author]])

# Combine every paper except our test case into a single corpus
whole_corpus = []
for author in authorsV:
    whole_corpus += lives_by_author_tokens[author]

# Get a frequency distribution
whole_corpus_freq_dist = list(nltk.FreqDist(whole_corpus).most_common(x)) # ! # X VARIABLE here! <--------- !
#whole_corpus_freq_dist[ 500:1000 ]

# %%
# Calculating features for each subcorpus

# The main data structure
features = [word for word,freq in whole_corpus_freq_dist]
feature_freqs = {}

for author in authorsV:
    # A dictionary for each candidate's features
    feature_freqs[author] = {}

    # A helper value containing the number of tokens in the author's subcorpus
    overall = len(lives_by_author_tokens[author])

    # Calculate each feature's presence in the subcorpus
    for feature in features:
        presence = lives_by_author_tokens[author].count(feature)
        feature_freqs[author][feature] = presence / overall

# %%
# Calculating feature averages and standard deviations

# The data structure into which we will be storing the "corpus standard" statistics
corpus_features = {}

# For each feature...
for feature in features:
    # Create a sub-dictionary that will contain the feature's mean
    # and standard deviation
    corpus_features[feature] = {}

    # Calculate the mean of the frequencies expressed in the subcorpora
    feature_average = 0
    for author in authorsV:
        feature_average += feature_freqs[author][feature]
    feature_average /= len(authors)
    corpus_features[feature]["Mean"] = feature_average

    # Calculate the standard deviation using the basic formula for a sample
    feature_stdev = 0
    for author in authorsV:
        diff = feature_freqs[author][feature] - corpus_features[feature]["Mean"]
        feature_stdev += diff*diff
    feature_stdev /= (len(authors) - 1)
    feature_stdev = math.sqrt(feature_stdev)
    corpus_features[feature]["StdDev"] = feature_stdev

# %%
# Calculating z-scores

feature_zscores = {}
for author in authorsV:
    feature_zscores[author] = {}
    for feature in features:

        # Z-score definition = (value - mean) / stddev
        # We use intermediate variables to make the code easier to read
        feature_val = feature_freqs[author][feature]
        feature_mean = corpus_features[feature]["Mean"]
        feature_stdev = corpus_features[feature]["StdDev"]
        feature_zscores[author][feature] = ((feature_val-feature_mean) /
                                            feature_stdev)

# %%
authorsV
# Out:
# ('Giambullari',
#  'Minerbetti',
#  'VasariPlusC',
#  'Bartoli',
#  'Ghiberti',
#  'Borghini',
#  'Sanga')

# %%
# Calculating features and z-scores for the "unkown" = disputed biographies

# Tokenize the test case
#testcase_tokens = nltk.word_tokenize(files_by_author["unkown"], language = 'italian')

testcase = 'unkown'

# Filter out punctuation and lowercase the tokens
testcase_tokens = tokens_by_author[testcase]


# Calculate the test case's features
overall = len(testcase_tokens)
testcase_freqs = {}
for feature in features:
    presence = testcase_tokens.count(feature)
    testcase_freqs[feature] = presence / overall

# Calculate the test case's feature z-scores
testcase_zscores = {}
for feature in features:
    feature_val = testcase_freqs[feature]
    feature_mean = corpus_features[feature]["Mean"]
    feature_stdev = corpus_features[feature]["StdDev"]
    testcase_zscores[feature] = (feature_val - feature_mean) / feature_stdev
    #print("Test case z-score for feature", feature, "is", testcase_zscores[feature])

# %%
# Calculate Delta
print('Compared to the biography: ' + testcase +   ' \n')
for author in authorsV:
    delta = 0
    for feature in features:
        delta += math.fabs((testcase_zscores[feature] -
                            feature_zscores[author][feature]))
    delta /= len(features)
    print( " - Delta score for candidate", author, "is", round(delta,4) )
    
print('\nthe nltk.FreqDist(whole_corpus).most_common(x) value was: ', x)
# Out:
# Compared to the biography: unkown
#
#  - Delta score for candidate Giambullari is 1.3544
#  - Delta score for candidate Minerbetti is 1.2006
#  - Delta score for candidate VasariPlusC is 0.853
#  - Delta score for candidate Bartoli is 1.0691
#  - Delta score for candidate Ghiberti is 1.3234
#  - Delta score for candidate Borghini is 1.1237
#  - Delta score for candidate Sanga is 1.3967
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  100

# %%
X = [20, 30, 40, 50, 70, 100] 

Borghini = [0.947, 1.1327,1.1032, 1.1178,1.1725, 1.1237  ]
Bartoli = [0.7078,0.8712, 0.8265,0.9037, 1.0659, 1.0691  ]
Giambullari = [1.1382, 1.2872,1.3676, 1.4525,1.4636 ,1.3544 ]
Vasari = [0.705,0.8943, 0.8003, 0.7559,0.7973,  0.853  ]
Minerbetti = [0.9967, 1.1809, 1.1788,1.1624, 1.2037, 1.2006 ]
Sanga = [0.8878,1.2924, 1.2948, 1.2585, 1.4306, 1.3967 ]
Ghiberti = [1.5337,1.3867,1.3634 ,1.3198, 1.3075, 1.3234  ]

# %% [markdown]
# # END OF NOTEBOOK

# %% [markdown]
# ## messy EXPERIMENTS AND TESTS

# %%
storage = []
for i in tokens_by_author:
    if 'Firenze' in tokens_by_author[i]:
        storage.append(tokens_by_author[i].count('Firenze')/len(tokens_by_author[i]))
        print(i, tokens_by_author[i].count('Firenze'))#/len(tokens_by_author[i]
    else:
        print(i)
        storage.append(0)
        
len(storage), len(tokens_by_author)

# %%
Firenze = pd.DataFrame()
Firenze['text'] = tokens_by_author.keys()
Firenze['count Firenze'] = storage
#disegno.sort_values('count disegno', ascending = False, inplace=True)
Firenze
# Out:
#            text  count Firenze
# 0            57       0.001437
# 1           167       0.001454
# 2           124       0.000413
# 3           138       0.000000
# 4            49       0.000723
# ..          ...            ...
# 174         134       0.001662
# 175           7       0.000528
# 176          30       0.001203
# 177         148       0.001695
# 178  Vasariplus       0.000000
#
# [179 rows x 2 columns]

# %%
store = []
for i in disegno['text']:
    if  i.endswith('.txt'):
        store.append(i.strip('.txt'))
    if (i[0]).isnumeric():
        for j in new:
            if i == j.split('_')[0]:
                store.append(j.split('_')[1])
    
    else:
        store.append(i)
    
    
len(store)    #tokens_by_author['144']
# Out:
# 179

# %%
#new

# %%
disegno['name'] = store
#disegno.sort_values('count disegno', inplace = True, ascending = False)

# %%
disegno[30:150]
# Out:
#            text  count disegno  \
# 30          105       0.001843
# 31          166       0.001612
# 32   Minerbetti       0.001478
# 33        other       0.000443
# 34           11       0.001376
# ..          ...            ...
# 145          17       0.001187
# 146          95       0.001144
# 147          92       0.001862
# 148          47       0.003784
# 149         150       0.001518
#
#                                                   name
# 30                                         Andrea-Tafi
# 31                 Tommaso-Fiorentino-detto-Giottino']
# 32                                          Minerbetti
# 33                                               other
# 34                             Nanni-dAntonio-di-Banco
# ..                                                 ...
# 145                                           Il-Rosso
# 146                           Michelagnolo-Buonarruoti
# 147                              Raffaellino-del-Garbo
# ...

# %%
disegno2 = pd.DataFrame()
disegno2 = disegno.sort_values(by = 'count disegno', ascending = False)
disegno2
# Out:
#     text  count disegno                                               name
# 112   18       0.005143                        Lorenzo-Monaco-degli-Angeli
# 13   145       0.004571                                   Lorenzo-di-Credi
# 15    19       0.004367               Proemio-della-terza-parte-delle-Vite
# 148   47       0.003784  Marcantonio-Bolognese-e-altri-intagliatori-di-...
# 109  151       0.003512                                    Marco-Calavrese
# ..   ...            ...                                                ...
# 111   46       0.000000                                           Gherardo
# 114  131       0.000000                            Bernardino-Pinturicchio
# 124  130       0.000000                                       Berna-Sanese
# 131   61       0.000000                                  Antonio-Viniziano
# 89    69       0.000000                                           Il-Cecca
#
# [179 rows x 3 columns]

# %%
stori = []
for i in range(179):
    stori.append(i)
disegno3 = pd.DataFrame()
disegno3['rank'] = stori
disegno3['disegno count relative'] = list(disegno2['count disegno'])
disegno3['name'] = list(disegno2['name'])
#disegno3[90:100]

# %%
disegno2['rank'] = range(179)
disegno2[:40]

# %%
disegno.to_csv('disegno-ranked.csv', index = False, header = True)

# %%
artists = os.listdir('./data/Datasets/Delta/')
artists = [i.strip('.txt').split('_') for i in artists]
#artists

# %%
with open('final_list.txt') as inpuf:
    finalart = inpuf.read()
finalart = (finalart.split(','))
new = []
for i in finalart:
    x = (i.strip('[').strip('\'').strip("'"))
    new.append(x.strip(" \'"))
new
# Out:
# ['0_Pesello-e-Francesco-Peselli',
#  '1_Pulidoro-da-Caravaggio-e-Maturino-Fiorentino',
#  '2_Cosimo-Rosselli',
#  '3_Andrea-Pisano',
#  '4_Giovan-Francesco-detto-il-Fattore-e-Pellegrino-da-Modana',
#  '5_Lazzaro-Vasari',
#  '6_Margaritone',
#  '7_Simone-Mosca',
#  '8_Iacopo-di-Casentino',
#  '9_Lorenzetto-e-Boccaccino',
#  '10_Pietro-Cavallini',
#  '11_Nanni-dAntonio-di-Banco',
#  '12_Desiderio-da-Settignano',
#  '13_Michele-San-Michele',
#  '14_Francesco-Granacci',
#  '15_Baccio-dAgnolo',
#  '16_Fra-GiovannAgnolo-Montorsoli',
#  '17_Il-Rosso',
#  '18_Lorenzo-Monaco-degli-Angeli',
#  '19_Proemio-della-terza-parte-delle-Vite',
#  '20_Fra-Bartolomeo-di-San-Marco',
#  '21_Giotto',
#  '22_Lorenzo-di-Bicci',
#  '23_Vellano-da-Padova',
#  '24_Tiziano-da-Cador',
#  '25_Giovanni-da-Ponte',
#  '26_Francesco-di-Giorgio-e-Lorenzo-Vecchietto',
#  '27_Daniello-Ricciarelli-da-Volterra',
#  '28_Diversi-artefici-italiani',
#  '29_Francesco-Francia',
#  '30_Taddeo-Gaddi',
#  '31_Andrea-del-Sarto',
# ...

# %% [markdown]
#  '9_Lorenzetto-e-Boccaccino',  '43_Filippo-Brunelleschi',  '95_Michelagnolo-Buonarruoti', '163_Giovannantonio-detto-il-Soddoma-da-Verzelli',  '149_Luca-Signorelli-da-Cortona',

# %% [markdown]
# ## Visualization

# %%
fig = plt.figure()

X = [20, 30, 40, 50, 100, 200, 2000, 5000, 7500, 10000] 

 #, 500, 1000

# Bartoli
Y1 = [1.838567213310585,1.7577106697854776,1.5905160467937012,1.4523928184962533, 1.6547129258282405, 1.8559837207812162, 1.447382305617218, 1.4238902538551055, 1.3635809672705872, 1.3574824743526004] 
plt.plot(X, Y1, label = "Bartoli") 

# Borghini
Y2 = [2.212588708509892, 2.1216984237448617, 1.9350455324941702, 1.8047511042785178, 1.7310287339170731, 1.9069649266433921, 1.3904418615732568, 1.3356429499408466, 1.3716397949147685, 1.218754065162964]
plt.plot(X, Y2, label = "Borghini") 

# Giambullari
Y3 = [2.3887643490055224, 2.134965208752774, 2.076301702793525, 2.089697790842044, 2.061855363803096, 2.1526371263687722, 1.6272694350761017, 1.3484106260054398, 1.2429869755393799, 1.0584340638156833]
plt.plot(X, Y3, label = "Giambullari") 

# Vasari
Y4 = [1.8931766640767909, 1.931615052520559, 1.6893137604038295, 1.591271219282905, 1.5978447600399246, 1.8195480012687923, 1.3756849118429249, 1.291135589191854, 1.2511525924497338, 1.134738413711443]
plt.plot(X, Y4, label = "Vasari", marker = "o") 

#Vcopy
Y5 = [2.1447275267148367, 2.16038276179463, 1.8748150015597838, 1.7585336358282706, 1.7595221289137672, 1.9867602944880658, 1.6250483882999922, 1.515776438240675, 1.4165442657836949, 1.2635989500315485]
plt.plot(X, Y5, label = "Vcopy") 

  
# Labeling the X-axis 
plt.xlabel('number of most common words') 
# Labeling the Y-axis 
plt.ylabel('Delta score') 
# Give a title to the graph
plt.title('Delta score distribution for every author concerning the authorship of the Lives\n') 

plt.xlim([0,8000])
plt.ylim([1.2, 2.0])
# Show a legend on the plot 
plt.legend() 
plt.show()
#plt.rcParams["figure.figsize"] = (10,5)

#plt.figure.figsize(14,6)

# %%
list(storage.values())
# Out:
# [[1.665621255180483,
#   1.4759970477168987,
#   1.4959279962612853,
#   1.3936248575260928,
#   1.468183137414862,
#   1.588321169797215,
#   1.8104327203906734],
#  [1.2512820121089012,
#   1.1918340402169294,
#   0.9087599615544902,
#   0.9314125024996363,
#   1.4144087204215077,
#   1.1600006588987801,
#   1.2350198874628364],
#  [1.3566461425569762,
#   1.283476631651887,
#   1.013979229715491,
#   1.0176337209912325,
#   1.5297539542799397,
#   1.2392394973236027,
#   1.3255176732985703],
#  [1.2713411082636494,
#   1.1933658721550342,
#   0.9484648171145872,
#   0.9574934560850993,
#   1.4206082699344276,
#   1.1715932223636805,
#   1.255242652734564],
#  [1.2740745356280663,
#   1.21285612128378,
#   0.9284564236393121,
#   0.9325956632449497,
#   1.437517601907932,
#   1.1906622572552346,
#   1.2503966804759192],
#  [1.2436114400254596,
#   1.2244473624183694,
#   0.8943019512978474,
#   0.9327608578485904,
#   1.400233307080375,
#   1.1795373577474648,
# ...

# %%
Y1 = []
for i in list(storage.values()):
    Y1.append(i[0]) 
len(Y1)
# Out:
# 168

# %%
#fig = plt.figure()
fig = plt.figure()

X = range(168) 

 #, 500, 1000

# Bartoli
Y1 = []
for i in list(storage.values()):
    Y1.append(i[0]) 
plt.plot(X, Y1, label = "Giambullari") 

# Borghini
Y2 = []
for i in list(storage.values()):
    Y2.append(i[1]) 
plt.plot(X, Y2, label = "Minerbetti") 

# Giambullari
Y3 = []
for i in list(storage.values()):
    Y3.append(i[2]) 
plt.plot(X, Y3, label = "Vasari +", marker = "o") 

# Vasari
Y4 = []
for i in list(storage.values()):
    Y4.append(i[3]) 
plt.plot(X, Y4, label = "Bartoli") 

#Vcopy
Y5 = []
for i in list(storage.values()):
    Y5.append(i[4]) 
plt.plot(X, Y5, label = "Ghiberti") 

Y6 = []
for i in list(storage.values()):
    Y6.append(i[5])
plt.plot(X, Y6, label = "Borghini") 

Y7 = []
for i in list(storage.values()):
    Y7.append(i[6]) 
plt.plot(X, Y7, label = "Sanga") 

  
# Labeling the X-axis 
#plt.xlabel('number of most common words') 
# Labeling the Y-axis 
plt.ylabel('Delta score') 
# Give a title to the graph
plt.title('Delta score distribution for every author candidate for every single biography\n') 

plt.xlim([0,168])
plt.ylim([0.65, 1.85])
# Show a legend on the plot 
plt.legend() 
plt.show()
#plt.rcParams["figure.figsize"] = (30,30)
fig.savefig('Deltascore-all-bios.jpg')
#plt.figure.figsize(30,6)

# %%
count = 0
for i, j in enumerate(Y3):
    print(i ,j)
    #count += 1
# Out:
# 0 1.4959279962612853
# 1 0.9087599615544902
# 2 1.013979229715491
# 3 0.9484648171145872
# 4 0.9284564236393121
# 5 0.8943019512978474
# 6 0.9955626461120171
# 7 0.983621212083726
# 8 0.8510489964619453
# 9 0.767618684495117
# 10 0.9279461839507434
# 11 0.8958702978674549
# 12 0.9347584837416792
# 13 0.8611126225426075
# 14 0.9851679280323485
# 15 1.0439208562117284
# 16 0.8739475480777058
# 17 1.0453919265326879
# 18 1.2014774552224428
# 19 1.140613633104238
# 20 1.0919289759745132
# 21 1.0306334006379134
# 22 1.0493733343954763
# 23 1.0843187201092899
# 24 1.2378867579296682
# 25 1.2831022613109988
# 26 1.177849898772447
# 27 0.9790767835538502
# 28 1.152163760456647
# 29 1.0024714113800821
# 30 1.1364710841708041
# 31 0.9086063417734089
# 32 1.192007901122374
# 33 1.012622658067186
# 34 1.0525277959822332
# 35 0.9470656392723547
# 36 1.2323020024053342
# 37 1.0225177489860464
# 38 0.9494003730973142
# 39 1.3293832323203396
# 40 1.0221933332748283
# 41 0.9885083884123557
# ...

# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.patches import Polygon
#
#
# def f(t):
#     return np.exp(-t) * np.cos(2*np.pi*t)
#
#
# t1 = np.arange(0.0, 3.0, 0.01)
#
# ax1 = plt.subplot(212)
# ax1.margins(0.05)           # Default margin is 0.05, value 0 means fit
# ax1.plot(t1, f(t1))
#
# ax2 = plt.subplot(221)
# ax2.margins(2, 2)           # Values >0.0 zoom out
# ax2.plot(t1, f(t1))
# ax2.set_title('Zoomed out')
#
# ax3 = plt.subplot(222)
# ax3.margins(x=0, y=-0.25)   # Values in (-0.5, 0.0) zooms in to center
# ax3.plot(t1, f(t1))
# ax3.set_title('Zoomed in')
#
# plt.show()
#
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/axes_margins.html#sphx-glr-gallery-subplots-axes-and-figures-axes-margins-py

# %%
s = Y3.sort()
s

# %% [markdown]
# ###

# %% [markdown]
# # Observation
#
# the bigger the set of .most common words, the closer Vasari himself to the biographies, in parallel Giambullari is catching up
#
# big rise between 100 and 200
#
# What kind of words are these words which causing this change?
#
# How big is the set in total?

# %%
#whole_corpus_freq_dist[:300]

# %% [markdown]
# [('che', 12468),
#  ('e', 9651),
#  ('di', 8122),
#  ('a', 5428),
#  ('non', 4553),
#  ('et', 4087),
#  ('la', 4058),
#  ('per', 3770),
#  ('il', 3570),
#  ('in', 3050),
#  ('io', 2962),
#  ('l', 2370),
#  ('si', 2316),
#  ('è', 2312),
#  ('mi', 2212),
#  ('le', 1931),
#  ('con', 1928),
#  ('vostra', 1818),
#  ('vi', 1757),
#  ('ho', 1742),
#  ('se', 1676),
#  ('da', 1612),
#  ('al', 1527),
#  ('del', 1462),
#  ('perché', 1360),
#  ('mio', 1267),
#  ('gli', 1262),
#  ('ha', 1240),
#  ('come', 1229),
#  ('questo', 1215),
#  ('un', 1212),
#  ('della', 1188),
#  ('sua', 1160),
#  ('signor', 1132),
#  ('voi', 1112),
#  ('più', 1110),
#  ('messer', 1076),
#  ('de', 1019),
#  ('ma', 952),
#  ('o', 944),
#  ('lo', 927),
#  ('ne', 927),
#  ('una', 913),
#  ('tutto', 897),
#  ('giorgio', 875),
#  ('molto', 869),
#  ('cosa', 858),
#  ('questa', 831),
#  ('signoria', 798),
#  ('i', 776),
#  ('cose', 765),
#  ('d', 764),
#  ('me', 758),
#  ('magnifico', 752),
#  ('quel', 740),
#  ('bene', 733),
#  ('altro', 723),
#  ('alla', 716),
#  ('eccellenza', 715),
#  ('quella', 707),
#  ('vostro', 688),
#  ('ci', 686),
#  ('sono', 650),
#  ('dio', 625),
#  ('fatto', 611),
#  ('quanto', 594),
#  ('son', 594),
#  ('far', 582),
#  ('così', 575),
#  ('delle', 569),
#  ('suo', 568),
#  ('vasari', 565),
#  ('ogni', 541),
#  ('sarà', 540),
#  ('tanto', 534),
#  ('sia', 531),
#  ('quale', 496),
#  ('mia', 495),
#  ('illustrissima', 493),
#  ('fare', 490),
#  ('fiorenza', 485),
#  ('nel', 451),
#  ('né', 447),
#  ('ora', 440),
#  ('dove', 440),
#  ('alli', 427),
#  ('poi', 425),
#  ('gran', 416),
#  ('qui', 416),
#  ('quando', 411),
#  ('però', 403),
#  ('s', 402),
#  ('duca', 392),
#  ('loro', 386),
#  ('ch', 369),
#  ('so', 366),
#  ('chi', 353),
#  ('dì', 350),
#  ('sopra', 350),
#  ('roma', 347),
#  ('ancora', 332),
#  ('opera', 330),
#  ('costì', 327),
#  ('fine', 321),
#  ('uno', 319),
#  ('quello', 319),
#  ('questi', 319),
#  ('già', 319),
#  ('servitore', 315),
#  ('nostro', 306),
#  ('n', 304),
#  ('ordine', 301),
#  ('lui', 298),
#  ('poco', 296),
#  ('modo', 295),
#  ('pur', 294),
#  ('nella', 288),
#  ('altra', 287),
#  ('fa', 286),
#  ('altri', 284),
#  ('detto', 284),
#  ('li', 282),
#  ('parte', 282),
#  ('stato', 282),
#  ('tutti', 280),
#  ('giovanni', 279),
#  ('sì', 273),
#  ('anche', 270),
#  ('queste', 263),
#  ('ella', 263),
#  ('grazia', 261),
#  ('prima', 257),
#  ('assai', 255),
#  ('qualche', 254),
#  ('dire', 253),
#  ('animo', 251),
#  ('quelle', 251),
#  ('dell', 250),
#  ('può', 249),
#  ('mano', 248),
#  ('caro', 247),
#  ('col', 246),
#  ('egli', 245),
#  ('esser', 244),
#  ('san', 243),
#  ('maestro', 243),
#  ('casa', 241),
#  ('signore', 236),
#  ('sala', 234),
#  ('credo', 232),
#  ('avete', 232),
#  ('altre', 231),
#  ('qua', 227),
#  ('tutte', 227),
#  ('meglio', 227),
#  ('senza', 222),
#  ('altezza', 219),
#  ('scudi', 219),
#  ('fussi', 218),
#  ('hanno', 215),
#  ('mai', 213),
#  ('aver', 212),
#  ('alle', 212),
#  ('dal', 211),
#  ('fu', 211),
#  ('intanto', 210),
#  ('volta', 207),
#  ('dico', 205),
#  ('vorrei', 205),
#  ('conto', 203),
#  ('m', 203),
#  ('pisa', 202),
#  ('grande', 201),
#  ('fino', 198),
#  ('quali', 195),
#  ('fra', 195),
#  ('lettera', 192),
#  ('ben', 191),
#  ('luogo', 190),
#  ('tutta', 188),
#  ('don', 186),
#  ('farò', 185),
#  ('tempo', 184),
#  ('illustrissimo', 184),
#  ('forse', 181),
#  ('acciò', 180),
#  ('era', 179),
#  ('mezzo', 179),
#  ('va', 178),
#  ('avendo', 178),
#  ('essere', 177),
#  ('principe', 177),
#  ('solo', 176),
#  ('dato', 173),
#  ('resto', 172),
#  ('vo', 171),
#  ('vostre', 169),
#  ('lei', 168),
#  ('dua', 168),
#  ('etc.', 168),
#  ('sempre', 166),
#  ('lettere', 166),
#  ('scritto', 165),
#  ('spedalingo', 165),
#  ('sotto', 164),
#  ('pure', 164),
#  ('santità', 163),
#  ('el', 163),
#  ('secondo', 162),
#  ('cavalier', 160),
#  ('sano', 160),
#  ('vero', 159),
#  ('batista', 159),
#  ('sta', 158),
#  ('farà', 158),
#  ('avessi', 157),
#  ('tenpo', 157),
#  ('virtù', 156),
#  ('via', 156),
#  ('presto', 155),
#  ('auto', 155),
#  ('francesco', 154),
#  ('firenze', 152),
#  ('amici', 152),
#  ('possa', 152),
#  ('siate', 150),
#  ('ché', 148),
#  ('avere', 148),
#  ('degli', 147),
#  ('arezzo', 147),
#  ('all', 146),
#  ('osservandissimo', 145),
#  ('noi', 145),
#  ('molte', 145),
#  ('vincenzo', 144),
#  ('insieme', 143),
#  ('pare', 143),
#  ('raccomando', 143),
#  ('posso', 142),
#  ('medesimo', 142),
#  ('ser', 140),
#  ('vedere', 139),
#  ('vita', 139),
#  ('tavola', 138),
#  ('arò', 137),
#  ('bisogna', 136),
#  ('buona', 136),
#  ('papa', 135),
#  ('parole', 135),
#  ('fo', 135),
#  ('male', 135),
#  ('que', 135),
#  ('dello', 132),
#  ('su', 132),
#  ('oggi', 132),
#  ('dalla', 131),
#  ('abbia', 130),
#  ('signori', 130),
#  ('facci', 130),
#  ('fratello', 129),
#  ('santa', 129),
#  ('senpre', 129),
#  ('allo', 126),
#  ('disegni', 126),
#  ('disegnio', 126),
#  ('dir', 125),
#  ('finito', 124),
#  ('anno', 124),
#  ('storie', 124),
#  ('state', 123),
#  ('palazzo', 123),
#  ('farei', 122),
#  ('nelle', 122),
#  ('dice', 122),
#  ('reverendo', 122),
#  ('mani', 121),
#  ('due', 121),
#  ('veggo', 120),
#  ('santo', 118),
#  ('ve', 117),
#  ('chiesa', 117),
#  ('borghini', 117),
#  ('bisognio', 117),
#  ('religione', 115),
#  ('troppo', 115),
#  ('vostri', 114),
#  ('molti', 114),
#  ('v', 114),
#  ('par', 113),
#  ('eccellentissimo', 113),
#  ('buon', 112),
#  ('qualcosa', 111),
#  ('cardinale', 110),
#  ('verso', 110),
#  ('intorno', 110),
#  ('sarò', 110),
#  ('venire', 110),
#  ('cioè', 109),
#  ('sue', 109),
#  ('cosimo', 108)]

# %% [markdown]
# [('ragionarne', 4),
#  ('doverrete', 4),
#  ('parlerò', 4),
#  ('esce', 4),
#  ('partiti', 4),
#  ('garbo', 4),
#  ('rimase', 4),
#  ('piacendoli', 4),
#  ('operate', 4),
#  ('gravità', 4),
#  ('cortese', 4),
#  ('buonarroto', 4),
#  ('misterio', 4),
#  ('risolver', 4),
#  ('quadretto', 4),
#  ('fussin', 4),
#  ('piacevole', 4),
#  ('mancherei', 4),
#  ('piglassi', 4),
#  ('oloferne', 4),
#  ('considerando', 4),
#  ('distendere', 4),
#  ('innamorato', 4),
#  ('bastassi', 4),
#  ('empiere', 4),
#  ('spedirò', 4),
#  ('altissimo', 4),
#  ('reputo', 4),
#  ('generoso', 4),
#  ('desiderrei', 4),
#  ('mel', 4),
#  ('saperrete', 4),
#  ('ripieno', 4),
#  ('sospeso', 4),
#  ('allegrezze', 4),
#  ('picture', 4),
#  ('zefiro', 4),
#  ('riposare', 4),
#  ('qualcuna', 4),
#  ('bozza', 4),
#  ('cattività', 4),
#  ('botte', 4),
#  ('opinione', 4),
#  ('similitudine', 4),
#  ('drieto', 4),
#  ('espresso', 4),
#  ('considerar', 4),
#  ('pictura', 4),
#  ('acanto', 4),
#  ('serbate', 4),
#  ('rimasi', 4),
#  ('seppi', 4),
#  ('ongni', 4),
#  ('tomerello', 4),
#  ('visite', 4),
#  ('legname', 4),
#  ('pie', 4),
#  ('vidi', 4),
#  ('tornino', 4),
#  ('imperatori', 4),
#  ('miglor', 4),
#  ('ragionamo', 4),
#  ('medaglia', 4),
#  ('potette', 4),
#  ('angulo', 4),
#  ('penserà', 4),
#  ('ven', 4),
#  ('riposarsi', 4),
#  ('privilegio', 4),
#  ('dura', 4),
#  ('julio', 4),
#  ('alias', 4),
#  ('seu', 4),
#  ('utili', 4),
#  ('tibi', 4),
#  ('aspettava', 4),
#  ('mellino', 4),
#  ('altrettanti', 4),
#  ('copie', 4),
#  ('attendo', 4),
#  ('rivedere', 4),
#  ('purgare', 4),
#  ('batte', 4),
#  ('ringraziarvi', 4),
#  ('compagno', 4),
#  ('altoviti', 4),
#  ('succede', 4),
#  ('cavando', 4),
#  ('uccelli', 4),
#  ('averci', 4),
#  ('minerbetti', 4),
#  ('xiiii', 4),
#  ('conseguire', 4),
#  ('fedele', 4),
#  ('truova', 4),
#  ('strani', 4),
#  ('gusci', 4),
#  ('inscrizione', 4),
#  ('fidei', 4),
#  ('commisso', 4),
#  ('abbiano', 4),
#  ('tirari', 4),
#  ('berna', 4),
#  ('frontone', 4),
#  ('particino', 4),
#  ('ulive', 4),
#  ('ancona', 4),
#  ('rimetterò', 4),
#  ('vere', 4),
#  ('pien', 4),
#  ('dialogo', 4),
#  ('debole', 4),
#  ('succederà', 4),
#  ('porge', 4),
#  ('sepultura', 4),
#  ('guasti', 4),
#  ('rimane', 4),
#  ('servissi', 4),
#  ('m.', 4),
#  ('fassi', 4),
#  ('servizi', 4),
#  ('publica', 4),
#  ('conte', 4),
#  ('isabella', 4),
#  ('salutare', 4),
#  ('guarderò', 4),
#  ('comuni', 4),
#  ('andatevi', 4),
#  ('guardate', 4),
#  ('darci', 4),
#  ('guasto', 4),
#  ('figluoli', 4),
#  ('straordinaria', 4),
#  ('crocifissaio', 4),
#  ('potessimo', 4),
#  ('scarsità', 4),
#  ('cristiano', 4),
#  ('penserei', 4),
#  ('replicato', 4),
#  ('febbraio', 4),
#  ('trovò', 4),
#  ('subietto', 4),
#  ('perpetuamente', 4),
#  ('dedicata', 4),
#  ('crocifissione', 4),
#  ('obbedire', 4),
#  ('ispedirmi', 4),
#  ('significare', 4),
#  ('luce', 4),
#  ('lunetta', 4),
#  ('sapienza', 4),
#  ('visione', 4),
#  ('rendere', 4),
#  ('entra', 4),
#  ('bere', 4),
#  ('rifare', 4),
#  ('parlereno', 4),
#  ('poder', 4),
#  ('conveniente', 4),
#  ('staia', 4),
#  ('fitti', 4),
#  ('dolere', 4),
#  ('avanzo', 4),
#  ('interesso', 4),
#  ('troppi', 4),
#  ('terrete', 4),
#  ('conoscessi', 4),
#  ('materie', 4),
#  ('spedirà', 4),
#  ('infermità', 4),
#  ('sapranno', 4),
#  ('brevi', 4),
#  ('paruto', 4),
#  ('capacie', 4),
#  ('seguente', 4),
#  ('tolga', 4),
#  ('trattenere', 4),
#  ('reni', 4),
#  ('esprimer', 4),
#  ('sapeva', 4),
#  ('eletto', 4),
#  ('istò', 4),
#  ('variare', 4),
#  ('qualch', 4),
#  ('petto', 4),
#  ('presta', 4),
#  ('tadda', 4),
#  ('seravezza', 4),
#  ('calculo', 4),
#  ('leviate', 4),
#  ('molt', 4),
#  ('lieva', 4),
#  ('materna', 4),
#  ('ir', 4),
#  ('diletta', 4),
#  ('mill', 4),
#  ('ordinata', 4),
#  ('giornate', 4),
#  ('fondata', 4),
#  ('giardino', 4),
#  ('mirabil', 4),
#  ('protezione', 4),
#  ('quadra', 4),
#  ('motti', 4),
#  ('affetionatissimo', 4),
#  ('galletto', 4),
#  ('ricordino', 4),
#  ('contentava', 4),
#  ('mei', 4),
#  ('parendovi', 4),
#  ('tacere', 4),
#  ('piaceva', 4),
#  ('dee', 4),
#  ('mutato', 4),
#  ('sacco', 4),
#  ('camini', 4),
#  ('sculture', 4),
#  ('pregandovi', 4),
#  ('portava', 4),
#  ('biagio', 4),
#  ('tenervi', 4),
#  ('verisimile', 4),
#  ('traverso', 4),
#  ('ritirato', 4),
#  ('liberi', 4),
#  ('soglio', 4),
#  ('purità', 4),
#  ('sollecitano', 4),
#  ('avevamo', 4),
#  ('felicita', 4),
#  ('durerà', 4),
#  ('avertite', 4),
#  ('mdlxvi', 4),
#  ('catafalco', 4),
#  ('noto', 4),
#  ('donò', 4),
#  ('genova', 4),
#  ('undici', 4),
#  ('operi', 4),
#  ('du', 4),
#  ('pirro', 4),
#  ('troverà', 4),
#  ('iudit', 4),
#  ('bernardetto', 4),
#  ('mattoni', 4),
#  ('fanciulla', 4),
#  ('corso', 4),
#  ('francioso', 4),
#  ('provato', 4),
#  ('tira', 4),
#  ('urbino', 4),
#  ('raguagliato', 4),
#  ('chiugga', 4),
#  ('dipositeria', 4),
#  ('restate', 4),
#  ('seguirà', 4),
#  ('antichità', 4),
#  ('salita', 4),
#  ('ecetto', 4),
#  ('paulino', 4),
#  ('ambrosio', 4),
#  ('stilicone', 4),
#  ('lodò', 4),
#  ('terrà', 4),
#  ('appoggio', 4),
#  ('cittadino', 4),
#  ('fiero', 4),
#  ('saputa', 4),
#  ('procurato', 4),
#  ('puntormo', 4),
#  ('raccomandassi', 4),
#  ('miracolosa', 4),
#  ('stufa', 4),
#  ('ottava', 4),
#  ('letterina', 4),
#  ('assetto', 4),
#  ('disfare', 4),
#  ('dimostra', 4),
#  ('agevolmente', 4),
#  ('militaris', 4),
#  ('milizia', 4),
#  ('comandare', 4),
#  ('damigelle', 4),
#  ('attenda', 4),
#  ('disagi', 4),
#  ('dolgo', 4),
#  ('rispondo', 4),
#  ('silenzio', 4),
#  ('intaglio', 4),
#  ('ragionerò', 4),
#  ('godervi', 4),
#  ('alloghi', 4),
#  ('sedici', 4),
#  ('doverranno', 4),
#  ('gravare', 4),
#  ('bernardino', 4),
#  ('custodia', 4),
#  ("ch'ella", 4),
#  ('salderà', 4),
#  ('diciotto', 4),
#  ('guidacci', 4),
#  ('aportatore', 4),
#  ('nanni', 4),
#  ('xxvi', 4),
#  ('viaggi', 4),
#  ('bisogniò', 4),
#  ('udito', 4),
#  ('mostrarvi', 4),
#  ('ecc.', 4),
#  ('stanpacie', 4),
#  ('restato', 4),
#  ('tra', 4),
#  ('pile', 4),
#  ('è.', 4),
#  ('orechi', 4),
#  ('portai', 4),
#  ('aviserà', 4),
#  ('gianbatista', 4),
#  ('scriverli', 4),
#  ('remunerazione', 4),
#  ('disegniata', 4),
#  ('basciandoli', 4),
#  ('mdlviiii', 4),
#  ('accenni', 4),
#  ('racconcia', 4),
#  ('maggiormente', 4),
#  ('risolvo', 4),
#  ('caccia', 4),
#  ('seguitano', 4),
#  ('zoppo', 4),
#  ('concini', 4),
#  ('stento', 4),
#  ('mdl', 4),
#  ('gnien', 4),
#  ('smarriti', 4),
#  ('nichie', 4),
#  ('tabernacoli', 4),
#  ('istudio', 4),
#  ('ardente', 4),
#  ('suto', 4),
#  ('sostegnio', 4),
#  ('passioni', 4),
#  ('soprali', 4),
#  ('guardando', 4),
#  ('terrestre', 4),
#  ('bocche', 4),
#  ('ricordandoli', 4),
#  ('restando', 4),
#  ('orvieto', 4),
#  ('sassetta', 4),
#  ('divinissimo', 4),
#  ('ecellenti', 4),
#  ('artifici', 4),
#  ('informato', 4),
#  ('basciar', 4),
#  ('saperrà', 4),
#  ('goderla', 4),
#  ('scolpito', 4),
#  ('portarvi', 4),
#  ('rispondono', 4),
#  ('concessi', 4),
#  ('acursio', 4),
#  ('oferto', 4),
#  ('amò', 4),
#  ('piglierà', 4),
#  ('presti', 4),
#  ('servirla', 4),
#  ('dispiaciuto', 4),
#  ('pescie', 4),
#  ('bracciano', 4),
#  ('fulignio', 4),
#  ('condussono', 4),
#  ('recato', 4),
#  ('ste', 4),
#  ('scusi', 4),
#  ('riceuti', 4),
#  ('consumare', 4),
#  ('some', 4),
#  ('provede', 4),
#  ('alloggio', 4),
#  ('spedendo', 4),
#  ('cottimo', 4),
#  ('mancarò', 4),
#  ('bini', 4),
#  ("ch'io", 4),
#  ('nasciere', 4),
#  ('gravi', 4),
#  ('raccomandare', 4),
#  ('informi', 4),
#  ('ogniun', 4),
#  ('saren', 4),
#  ('lasso', 4),
#  ('quindici', 4),
#  ('sonetti', 4),
#  ('disperato', 4),
#  ('diavolo', 4),
#  ('viiii', 4),
#  ('apostolo', 4),
#  ('tormi', 4),
#  ('lasciai', 4),
#  ('navicellaio', 4),
#  ('lucigniano', 4),
#  ('romano', 4),
#  ('baldini', 4),
#  ('meni', 4),
#  ('ufizii', 4),
#  ("d'arezzo", 4),
#  ('avergli', 4),
#  ('dessidererebbe', 4),
#  ('gori', 4),
#  ('polvere', 4),
#  ('rivederla', 4),
#  ('muli', 4),
#  ('alzar', 4),
#  ('assegniamento', 4),
#  ('mettino', 4),
#  ('lapis', 4),
#  ('datelo', 4),
#  ('satiffatto', 4),
#  ('raccomandiano', 4),
#  ('salgano', 4),
#  ('cesis', 4),
#  ('maffeo', 4),
#  ('pesi', 4),
#  ('pompa', 4),
#  ('lunghezze', 4),
#  ('conmesso', 4),
#  ('arivare', 4),
#  ('luminoso', 4),
#  ('mila', 4),
#  ('ciè', 4),
#  ('intenderà', 4),
#  ('ricolte', 4),
#  ('appieno', 4),
#  ('conmesse', 4),
#  ('aparato', 4),
#  ('insegnie', 4),
#  ('splendor', 4),
#  ('dorato', 4),
#  ('nocie', 4),
#  ('toglie', 4),
#  ('travagliar', 4),
#  ('nanzi', 4),
#  ('omnes', 4),
#  ('fanciulle', 4),
#  ('faren', 4),
#  ('valle', 4),
#  ('eron', 4),
#  ('grossezza', 4),
#  ('comoda', 4),
#  ('lista', 4),
#  ('r', 4),
#  ('rose', 4),
#  ('finì', 4),
#  ('procuri', 4),
#  ('ogniora', 4),
#  ('arcivescovo', 4),
#  ('quaranta', 4),
#  ('deliberare', 4),
#  ('tribolata', 4),
#  ('acenni', 4),
#  ('basciato', 4),
#  ('tenghino', 4),
#  ('ganbe', 4),
#  ('pontificato', 4),
#  ('dimanda', 4),
#  ('brescia', 4),
#  ('facciasi', 4),
#  ('funmo', 4),
#  ('signior', 4),
#  ('perfettamente', 4),
#  ('molestarla', 4),
#  ('excellenza', 4),
#  ('progenitori', 4),
#  ('benefizi', 4),
#  ('lassar', 4),
#  ('portano', 4),
#  ('spirituale', 4),
#  ('fè', 4),
#  ('bargello', 4),
#  ('afectione', 4),
#  ('stanpe', 4),
#  ('suplicato', 4),
#  ('porfidi', 4),
#  ('gloriosa', 4),
#  ('veniano', 4),
#  ('baldachino', 4),
#  ('scomodo', 4),
#  ('pili', 4),
#  ('tuto', 4),
#  ('rocco', 4),
#  ('ruosi', 4),
#  ('quattordici', 4),
#  ('esaia', 4),
#  ('acque', 4),
#  ('confinato', 3),
#  ('afflitto', 3),
#  ('arrivata', 3),
#  ('satisfaccino', 3),
#  ('imperadore', 3),
#  ('prudentemente', 3),
#  ('sponsalizio', 3),
#  ('stanca', 3),
#  ('lauro', 3),
#  ('magnanimità', 3),
#  ('fareli', 3),
#  ('quercia', 3),
#  ('riposassi', 3),
#  ('cacciata', 3),
#  ('vt', 3),
#  ('bacino', 3),
#  ('mercurio', 3),
#  ('fuga', 3),
#  ('intenderei', 3),
#  ('iudizio', 3),
#  ('europa', 3),
#  ('castrazione', 3),
#  ('creare', 3),
#  ('elementi', 3),
#  ('creato', 3),
#  ('genitali', 3),
#  ('gittò', 3),
#  ('possibilità', 3),
#  ('concilio', 3),
#  ('potenzie', 3),
#  ('severità', 3),
#  ('triompho', 3),
#  ('confessione', 3),
#  ('fondo', 3),
#  ('elevato', 3),
#  ('quinta', 3),
#  ('corone', 3),
#  ('apparissi', 3),
#  ('nugole', 3),
#  ('tagliati', 3),
#  ('ragioneremo', 3),
#  ('fateli', 3),
#  ('mettersi', 3),
#  ('virtute', 3),
#  ('giovanetto', 3),
#  ('servitori', 3),
#  ('percioché', 3),
#  ('seppe', 3),
#  ('suona', 3),
#  ('prigioni', 3),
#  ('ali', 3),
#  ('palma', 3),
#  ('zuffa', 3),
#  ('providenzia', 3),
#  ('ab', 3),
#  ('velluto', 3),
#  ('matrona', 3),
#  ('ingegneri', 3),
#  ('inimici', 3),
#  ('marte', 3),
#  ('moltitudine', 3),
#  ('fuochi', 3),
#  ('nudo', 3),
#  ('furore', 3),
#  ('sonando', 3),
#  ('nachere', 3),
#  ('significato', 3),
#  ('padrona', 3),
#  ('selve', 3),
#  ('erbe', 3),
#  ('produce', 3),
#  ('abondanzia', 3),
#  ('chiamata', 3),
#  ('scuro', 3),
#  ('primavera', 3),
#  ('ambe', 3),
#  ('sottile', 3),
#  ('valetevi', 3),
#  ('fanghi', 3),
#  ('esito', 3),
#  ('ricordiate', 3),
#  ('vedesti', 3),
#  ('fatale', 3),
#  ('cosaccie', 3),
#  ('colpi', 3),
#  ('storpiati', 3),
#  ('pena', 3),
#  ('essendomi', 3),
#  ('incominciato', 3),
#  ('fronte', 3),
#  ('sicut', 3),
#  ('ita', 3),
#  ('homines', 3),
#  ('lassa', 3),
#  ('sentenzia', 3),
#  ('beato', 3),
#  ('pregovi', 3),
#  ('palazo', 3),
#  ('felici', 3),
#  ('cavallino', 3),
#  ('ragionammo', 3),
#  ('serviranno', 3),
#  ('mandatavi', 3),
#  ('prua', 3),
#  ('cercherò', 3),
#  ('caminar', 3),
#  ('maximo', 3),
#  ('scemando', 3),
#  ('crescono', 3),
#  ('eserciti', 3),
#  ('morta', 3),
#  ('stracca', 3),
#  ('liberazione', 3),
#  ('rossa', 3),
#  ('presentassi', 3),
#  ('intendessi', 3),
#  ('fareste', 3),
#  ('ghirlanda', 3),
#  ('arrivare', 3),
#  ('volle', 3),
#  ('coperta', 3),
#  ('assedio', 3),
#  ('cremona', 3),
#  ('approvato', 3),
#  ('valse', 3),
#  ('morendo', 3),
#  ('parente', 3),
#  ('verdi', 3),
#  ('crescere', 3),
#  ('amalato', 3),
#  ('conclusione', 3),
#  ('gola', 3),
#  ('degnità', 3),
#  ('galante', 3),
#  ('perduto', 3),
#  ('prontissimo', 3),
#  ('occorso', 3),
#  ('dolersi', 3),
#  ('guastar', 3),
#  ('accettar', 3),
#  ('rimedii', 3),
#  ('amandovi', 3),
#  ('ordinerete', 3),
#  ('tornarvene', 3),
#  ('preservarvi', 3),
#  ('scrivevo', 3),
#  ('lietamente', 3),
#  ('ottimi', 3),
#  ('costano', 3),
#  ('intagliati', 3),
#  ('vedendomi', 3),
#  ('ricordassi', 3),
#  ('godo', 3),
#  ('scoppio', 3),
#  ('strasordinario', 3),
#  ('grandeza', 3),
#  ('volendomi', 3),
#  ('voglion', 3),
#  ('dolcemente', 3),
#  ('conversazione', 3),
#  ('servirli', 3),
#  ('tedesco', 3),
#  ('raccomandomi', 3),
#  ('maravigliate', 3),
#  ('adietro', 3),
#  ('bono', 3),
#  ('strutto', 3),
#  ('tarda', 3),
#  ('lascerà', 3),
#  ('superata', 3),
#  ('vincere', 3),
#  ('omnia', 3),
#  ('azzurri', 3),
#  ('avrete', 3),
#  ('decembre', 3),
#  ('martelli', 3),
#  ('satisfarete', 3),
#  ('legger', 3),
#  ('seguirò', 3),
#  ('satisfattissimo', 3),
#  ('temete', 3),
#  ('paro', 3),
#  ('arrivato', 3),
#  ('destinato', 3),
#  ('indugiato', 3),
#  ('finirlo', 3),
#  ('mandarli', 3),
#  ('coda', 3),
#  ('immortale', 3),
#  ('azurri', 3),
#  ('avisare', 3),
#  ('veli', 3),
#  ('bisognato', 3),
#  ('medoro', 3),
#  ('giocondissima', 3),
#  ('incominciata', 3),
#  ('entrerrò', 3),
#  ('ingrossar', 3),
#  ('chiesti', 3),
#  ('consolare', 3),
#  ('consigliato', 3),
#  ('rispondetemi', 3),
#  ('trovano', 3),
#  ('costò', 3),
#  ('servita', 3),
#  ('riverenzia', 3),
#  ('ordinarii', 3),
#  ('mandativi', 3),
#  ('vederle', 3),
#  ('rispondete', 3),
#  ('essequie', 3),
#  ('tornarmene', 3),
#  ('avesti', 3),
#  ('eroi', 3),
#  ('fili', 3),
#  ('dicevi', 3),
#  ('cervelli', 3),
#  ('guadagni', 3),
#  ('disegnando', 3),
#  ('partirsi', 3),
#  ('attenenti', 3),
#  ('doppia', 3),
#  ('adoperate', 3),
#  ('desideroso', 3),
#  ('bona', 3),
#  ('mostrarli', 3),
#  ('coperte', 3),
#  ('magno', 3),
#  ('raccomandiamo', 3),
#  ('affanni', 3),
#  ('doglia', 3),
#  ('intagliare', 3),
#  ('accusate', 3),
#  ('uccellato', 3),
#  ('pregai', 3),
#  ('bassi', 3),
#  ('prove', 3),
#  ('volendone', 3),
#  ('compagni', 3),
#  ('frutte', 3),
#  ('ridotta', 3),
#  ('stupenda', 3),
#  ('distender', 3),
#  ('lodare', 3),
#  ('pesci', 3),
#  ('remi', 3),
#  ('chiamano', 3),
#  ('rispondendo', 3),
#  ('femine', 3),
#  ('finto', 3),
#  ('albero', 3),
#  ('basciano', 3),
#  ('volea', 3),
#  ('incominciate', 3),
#  ('venissino', 3),
#  ('veneziani', 3),
#  ('fateci', 3),
#  ('burla', 3),
#  ('acerbo', 3),
#  ('battezzare', 3),
#  ('convenga', 3),
#  ('sicurissimo', 3),
#  ('intervenga', 3),
#  ('indirizzi', 3),
#  ('fini', 3),
#  ('confortato', 3),
#  ('sorelle', 3),
#  ('figliuola', 3),
#  ('tributo', 3),
#  ('ripari', 3),
#  ('sù', 3),
#  ('polizze', 3),
#  ('mirabile', 3),
#  ('intenebrata', 3),
#  ('sente', 3),
#  ('volgo', 3),
#  ('negligenzia', 3),
#  ('piglerebbe', 3),
#  ('dat', 3),
#  ('credessi', 3),
#  ('dividere', 3),
#  ('fugge', 3),
#  ('combattere', 3),
#  ('metterebbe', 3),
#  ('accommoda', 3),
#  ('quinti', 3),
#  ('spigoli', 3),
#  ('consolo', 3),
#  ('volerlo', 3),
#  ('cammini', 3),
#  ('consiglare', 3),
#  ('negoziarla', 3),
#  ('medico', 3),
#  ('ingannare', 3),
#  ('corti', 3),
#  ('andarci', 3),
#  ('facili', 3),
#  ('saluto', 3),
#  ('porci', 3),
#  ('assolutamente', 3),
#  ('monasterii', 3),
#  ('indirizzo', 3),
#  ('increscie', 3),
#  ('muovo', 3),
#  ('orecchi', 3),
#  ('conservare', 3),
#  ('ideo', 3),
#  ('guglielmo', 3),
#  ('sonmi', 3),
#  ('desinar', 3),
#  ('comparazione', 3),
#  ('riuscita', 3),
#  ('perdona', 3),
#  ('naso', 3),
#  ('promette', 3),
#  ("ch'el", 3),
#  ('architettor', 3),
#  ('buonora', 3),
#  ('addosso', 3),
#  ('grand', 3),
#  ('invidie', 3),
#  ('fondamenti', 3),
#  ('fermò', 3),
#  ('avvisato', 3),
#  ('sottoposte', 3),
#  ('occorrere', 3),
#  ('maiestà', 3),
#  ('granai', 3),
#  ('franco', 3),
#  ('volevi', 3),
#  ('rilieva', 3),
#  ('crudele', 3),
#  ('niuna', 3),
#  ('disegnar', 3),
#  ('armadii', 3),
#  ('provincie', 3),
#  ('germania', 3),
#  ('graziosa', 3),
#  ('mantenere', 3),
#  ('novelle', 3),
#  ('giotto', 3),
#  ('copiosa', 3),
#  ('aggiugnervi', 3),
#  ('gallo', 3),
#  ('tasso', 3),
#  ('filosofia', 3),
#  ('dottrina', 3),
#  ('passatempo', 3),
#  ('solitudine', 3),
#  ('duriate', 3),
#  ('mdlxiiii', 3),
#  ('qualunque', 3),
#  ('celo', 3),
#  ('accrescimento', 3),
#  ('nobile', 3),
#  ('mettermi', 3),
#  ('nobilissimi', 3),
#  ('facilitare', 3),
#  ('rene', 3),
#  ('cavalcar', 3),
#  ('starmi', 3),
#  ('perle', 3),
#  ('staranno', 3),
#  ('ogn', 3),
#  ('ritrovar', 3),
#  ('leggo', 3),
#  ('uom', 3),
#  ('amaro', 3),
#  ('rapporto', 3),
#  ('piovuto', 3),
#  ('guadagno', 3),
#  ('sadisfare', 3),
#  ('largamente', 3),
#  ('occorrenzie', 3),
#  ('dormito', 3),
#  ('accomodato', 3),
#  ('edificato', 3),
#  ('apparve', 3),
#  ('paressino', 3),
#  ('contrasegni', 3),
#  ('aggiugnessi', 3),
#  ('fuggir', 3),
#  ('nave', 3),
#  ('consideriate', 3),
#  ('verrebbono', 3),
#  ('crederei', 3),
#  ('giustissimo', 3),
#  ('apparisca', 3),
#  ('termina', 3),
#  ('travagliata', 3),
#  ('longobardi', 3),
#  ('dichiarassi', 3),
#  ('dipigne', 3),
#  ('gusti', 3),
#  ('disgrazie', 3),
#  ('dimandare', 3),
#  ('passasse', 3),
#  ('mula', 3),
#  ('seguissi', 3),
#  ('dipintore', 3),
#  ('sommi', 3),
#  ('propio', 3),
#  ('quietamente', 3),
#  ('garbata', 3),
#  ('riguardo', 3),
#  ('concistoro', 3),
#  ('accadrà', 3),
#  ('pensiamo', 3),
#  ('adamo', 3),
#  ('pagolo', 3),
#  ('minuto', 3),
#  ('rimandare', 3),
#  ('pose', 3),
#  ('rimarrà', 3),
#  ('sospetti', 3),
#  ('perdonatemi', 3),
#  ('suocero', 3),
#  ('bonsi', 3),
#  ('veggendo', 3),
#  ('amorevolmente', 3),
#  ('mantenercelo', 3),
#  ('adirato', 3),
#  ('accadere', 3),
#  ('bisognassino', 3),
#  ('sapersi', 3),
#  ('appartenenti', 3),
#  ('mostrargli', 3),
#  ('picoli', 3),
#  ('abbracciate', 3),
#  ('sostengono', 3),
#  ('alloro', 3),
#  ('ambedue', 3),
#  ('arebbono', 3),
#  ('fatemi', 3),
#  ('iulio', 3),
#  ('essendosi', 3),
#  ('impedimento', 3),
#  ('priori', 3),
#  ('b.', 3),
#  ('cum', 3),
#  ('quem', 3),
#  ('regimen', 3),
#  ('hospitalis', 3),
#  ('etiam', 3),
#  ('dicti', 3),
#  ('ipsum', 3),
#  ('nos', 3),
#  ('alia', 3),
#  ('sub', 3),
#  ('quo', 3),
#  ('hospitale', 3),
#  ('eius', 3),
#  ('tenore', 3),
#  ('an', 3),
#  ('assicurato', 3),
#  ('congregazione', 3),
#  ('datogli', 3),
#  ('buio', 3),
#  ('interrotto', 3),
#  ('divisa', 3),
#  ('numeri', 3),
#  ('rifatta', 3),
#  ('riavermi', 3),
#  ('giudichi', 3),
#  ('epitafii', 3),
#  ('significata', 3),
#  ('avendoci', 3),
#  ('proemio', 3),
#  ('monasterio', 3),
#  ('accompagnati', 3),
#  ('speco', 3),
#  ('tessitore', 3),
#  ('miglorando', 3),
#  ('tornava', 3),
#  ('domane', 3),
#  ('fanciulli', 3),
#  ('gentilmente', 3),
#  ('chieggo', 3),
#  ('dimestichezza', 3),
#  ('quantumque', 3),
#  ('tenete', 3),
#  ('ottenere', 3),
#  ('presidente', 3),
#  ('mercanti', 3),
#  ('vogl', 3),
#  ('bindo', 3),
#  ('dirla', 3),
#  ('mera', 3),
#  ('stetti', 3),
#  ('potetti', 3),
#  ('patisce', 3),
#  ('savi', 3),
#  ('comunque', 3),
#  ('chiamò', 3),
#  ('meritamente', 3),
#  ('are', 3),
#  ('quadrino', 3),
#  ('starne', 3),
#  ('principii', 3),
#  ('tardo', 3),
#  ('ragguagliato', 3),
#  ('parea', 3),
#  ('portiate', 3),
#  ('mandatami', 3),
#  ('perficiebat', 3)]

# %%
#(feature_zscores['Giambullari'].keys())

# %%
test = ['mancheranno', 'navarra', 'conferire', 'griselli', 'nevi', 'pelo', 'sonar', 'campane', 'facea', 'valer', 'dicendomi', 'opure', 'azioni', 'santissimi', 'esteriore', 'governata', 'gesù', 'trasfigurazione', 'mostrandosi', 'risolverete', 'istoriette', 'pro', 'corrispondente', 'facendolo', 'cospetto', 'solenne', 'vesti', 'reti', 'eris', 'capiens', 'significando', 'corrisponderebbe', 'alludendo', 'fermezza', 'fides', 'svper', 'tenesse', 'figurerei', 'evangelica', 'scire', 'porrei', 'dominum', 'separata', 'tornerebbe', 'cotal', 'tum', 'ricevé', 'potenza', 'corvi', 'melchisedech', 'reali', 'mago', 'aiutargli', 'capaci', 'spazi', 'quattrini', 'impedisse', 'procuratori', 'esserci', 'seguisse', 'risolvermi', 'oda', 'privata', 'comporta', 'inresoluto', 'andiamo', 'metterci', 'spediente', 'crediate', 'pone', 'vaglion', 'ragionate', 'computo', 'tornono', 'dolete', 'benedetti', 'convenisse', 'margine', 'vennon', 'discreto', 'misera', 'onorati', 'ingegnatevi', 'accomodi', 'apparenza', 'affetti', 'profondo', 'giovamento', 'cirimonia', 'rispondervi', 'subietti', 'sforzarsi', 'impedire', 'credetemi', 'michel', 'ridolfo', 'toccare', 'piglasse', 'pagarle', 'giudicherete', 'contenuto', 'guiducci', 'parlerete', 'dicessimo', 'specificare', 'comperò', 'riverenza', 'parlate', 'temere', 'lettuccio', 'privilegi', 'ostica', 'compreso', 'aveamo', 'ridete', 'verificassi', 'saperrò', 'cavassi', 'capitare', 'corpus', 'ristori', 'uova', 'dissimulare', 'pratiche', 'offenderlo', 'intorbidare', 'tunisi', 'ferdinando', 'vienna', 'furie', 'gara', 'facendone', 'dedicarle', 'risponderanno', 'offeriscono', 'damiata', 'edificazione', 'accomodarla', 'accennata', 'variando', 'diversa', 'vitae', 'ornar', 'carraia', 'angioletti', 'corrispondenza', 'vigna', 'teatro', 'lasciava', 'cavalchi', 'muore', 'avemo', 'tentoni', 'medagle', 'marcia', 'claudio', 'straccai', 'trita', 'adoperar', 'grotesche', 'mettevo', 'ditene', 'distinti', 'rimanemmo', 'girandole', 'stimato', 'stimati', 'restono', 'debb', 'ragionevol', 'fermassi', 'disfatti', 'forsi', 'sapra', 'fattivo', 'accadeva', 'standovi', 'orecchio', 'dante', 'figliuole', 'leo', 'ostante', 'conferirlo', 'adoperano', 'smarrito', 'maravigliosamente', 'udite', 'rispondermi', 'cedola', 'rimaso', 'murate', 'vicine', 'convenevole', 'violenta', 'sangalletti', 'considerasse', 'usufrutti', 'terminando', 'scoprì', 'vago', 'replicando', 'nonnulla', 'berlingozzo', 'ambasciadore', 'fiorita', 'diceria', 'condussi', 'renderà', 'chiamati', 'narrata', 'stravagante', 'supplisca', 'degnerà', 'dicessino', 'truovi', 'stargli', 'espettazione', 'piega', 'capegli', 'insegnare', 'sollecitino', 'dubitato', 'voglino', 'aposta', 'protesto', 'inpedissino', 'bastandomi', 'salutarvi', 'fur', 'eredi', 'cugini', 'porzione', 'volessin', 'erectam', 'decoratam', 'pontt', 'perfectam', 'ipse', 'georgio', 'vasario', 'sui', 'adì', 'confermare', 'stringnere', 'schifa', 'dispiacerebbe', 'ninfa', 'pesce', 'occupano', 'chiocciole', 'vaghe', 'vaga', 'aqque', 'presentare', 'ricorderò', 'ar', 'durabili', 'ix', 'replicar', 'accommodata', 'bugiardino', 'saccone', 'troviate', 'ritrovato', 'fattogli', 'reggio', 'mettervele', 'sancta', 'ragionasti', 'religiosi', 'tobbia', 'mariti', 'angelica', 'difendono', 'liberano', 'distribuzione', 'acconciò', 'continuando', 'corrispondendo', 'allato', 'ecce', 'ego', 'creatore', 'superbo', 'bambini', 'fiamme', 'valentuomini', 'angiolo', 'considerabile', 'improvisto', 'multiplichino', 'teologia', 'formare', 'gentiluomini', 'eretici', 'predicando', 'sentì', 'discordie', 'leggono', 'avertiteci', 'variar', 'seder', 'vinse', 'delizie', 'storiette', 'gemma']

# %%
#np.array(feature_zscores['Giambullari'])

# %% [markdown]
# - Delta score for candidate Minerbetti is 1.230418889077193
# - Delta score for candidate Ghiberti is 1.7984273356987088
# - Delta score for candidate Vasari is 0.9850227573087175
# - Delta score for candidate Bartoli is 1.025564894053417
# - Delta score for candidate Vasaric is 0.9110218362265275
# - Delta score for candidate Borghini is 1.3471690190634988
# - Delta score for candidate Sanga is 1.1975554654949234
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9125282615350297
# - Delta score for candidate Borghini is 1.1959076881930026
# - Delta score for candidate Giambullari is 1.440524415313832
# - Delta score for candidate Vasari+ is 0.8659680072718681
# - Delta score for candidate Ghiberti is 1.66255780735611
# - Delta score for candidate Minerbetti is 1.1113846121584523
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.9669242476531033
# - Delta score for candidate Borghini is 1.316883590791107
# - Delta score for candidate Giambullari is 1.4582268660722033
# - Delta score for candidate Vasari+ is 1.0490335242713955
# - Delta score for candidate Ghiberti is 1.5954035048774255
# - Delta score for candidate Minerbetti is 1.325240052145496
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  30 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9725715272560551
# - Delta score for candidate Borghini is 1.2704746653153534
# - Delta score for candidate Giambullari is 1.5033611780526448
# - Delta score for candidate Vasari+ is 0.9733864959444072
# - Delta score for candidate Ghiberti is 1.4820937390954068
# - Delta score for candidate Minerbetti is 1.2605394703764703
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  40 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9976580040378855
# - Delta score for candidate Borghini is 1.2495293933027343
# - Delta score for candidate Giambullari is 1.6029327063638343
# - Delta score for candidate Vasari+ is 0.9056941136578458
# - Delta score for candidate Ghiberti is 1.4084153958851295
# - Delta score for candidate Minerbetti is 1.282559628959885
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  50 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9955146893619015
# - Delta score for candidate Borghini is 1.2915474435939935
# - Delta score for candidate Giambullari is 1.5726773252261448
# - Delta score for candidate Vasari+ is 0.9532003499625356
# - Delta score for candidate Ghiberti is 1.768863296229559
# - Delta score for candidate Minerbetti is 1.185479057845324
# - Delta score for candidate Sanga is 1.166182219250814
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 1.0487522225408912
# - Delta score for candidate Borghini is 1.364836918105319
# - Delta score for candidate Giambullari is 1.461425698468591
# - Delta score for candidate Vasari+ is 1.0470952420608943
# - Delta score for candidate Ghiberti is 1.5992095849097903
# - Delta score for candidate Minerbetti is 1.3564529035762793
# - Delta score for candidate Sanga is 1.4535659049884064
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  30 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9499412118158619
# - Delta score for candidate Borghini is 1.2918354406878685
# - Delta score for candidate Giambullari is 1.4936637387858733
# - Delta score for candidate Vasari+ is 0.9514157532588525
# - Delta score for candidate Ghiberti is 1.5085936117953398
# - Delta score for candidate Minerbetti is 1.2496156016120816
# - Delta score for candidate Sanga is 1.3830727921931874
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  40 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.9512208116842088
# - Delta score for candidate Borghini is 1.2427958293216204
# - Delta score for candidate Giambullari is 1.5534382448314088
# - Delta score for candidate Vasari+ is 0.8814160319083328
# - Delta score for candidate Ghiberti is 1.3856607875182831
# - Delta score for candidate Minerbetti is 1.2329124448578563
# - Delta score for candidate Sanga is 1.3991147461970106
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  50 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9972291630757668
# - Delta score for candidate Borghini is 1.296403752112832
# - Delta score for candidate Giambullari is 1.5743547376695197
# - Delta score for candidate Vasari is 0.9814708034086305
# - Delta score for candidate Ghiberti is 1.7735743059592533
# - Delta score for candidate Minerbetti is 1.1871102027088463
# - Delta score for candidate Sanga is 1.1661398193882788
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 1.008177641111247
# - Delta score for candidate Borghini is 1.3426003402387119
# - Delta score for candidate Giambullari is 1.397859268785851
# - Delta score for candidate Vasari is 1.0355263128575716
# - Delta score for candidate Ghiberti is 1.496890928576977
# - Delta score for candidate Minerbetti is 1.3109403795535515
# - Delta score for candidate Sanga is 1.4319635052681348
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  30 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.9409680566935892
# - Delta score for candidate Borghini is 1.271307210656803
# - Delta score for candidate Giambullari is 1.4772876023615515
# - Delta score for candidate Vasari is 1.0109438225779745
# - Delta score for candidate Ghiberti is 1.4756803317985265
# - Delta score for candidate Minerbetti is 1.239484333863618
# - Delta score for candidate Sanga is 1.413307941202701
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  40 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.9751318598043076
# - Delta score for candidate Borghini is 1.2182037475340228
# - Delta score for candidate Giambullari is 1.521781467358703
# - Delta score for candidate Vasari is 0.9405080772321049
# - Delta score for candidate Ghiberti is 1.3877667910444293
# - Delta score for candidate Minerbetti is 1.2023713034846664
# - Delta score for candidate Sanga is 1.3580860754335256
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  50 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 1.4004546585014468
# - Delta score for candidate Borghini is 1.3046956771637306
# - Delta score for candidate Giambullari is 1.32597782821712
# - Delta score for candidate Vasari+ is 1.2881411302394081
# - Delta score for candidate Ghiberti is 1.6272247795977284
# - Delta score for candidate Minerbetti is 1.3968633833714634
# - Delta score for candidate Sanga is 1.4293196028736699
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  7000 ; tokenizer: language = 'italian'
#
#
# # Test with the whole Vite
#
#
#
# - Delta score for candidate Bartoli is 0.9861999007447985
# - Delta score for candidate Borghini is 1.284376232179408
# - Delta score for candidate Giambullari is 1.5454953560204459
# - Delta score for candidate Vasari is 0.9956052715725201
# - Delta score for candidate Ghiberti is 1.754960369852709
# - Delta score for candidate Minerbetti is 1.1843475695405605
# - Delta score for candidate Sanga is 1.1440358637761574
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.8117562658414927
# - Delta score for candidate Borghini is 1.0530810468345162
# - Delta score for candidate Giambullari is 1.2663817291845656
# - Delta score for candidate Vasari is 0.8030149953519017
# - Delta score for candidate Vcopy is 0.8406950159916262
# - Delta score for candidate Ghiberti is 1.4971966313429645
# - Delta score for candidate Minerbetti is 0.9898039007416557
# - Delta score for candidate Sanga is 0.9144098511095434
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9843033355131554
# - Delta score for candidate Borghini is 1.2822332683581057
# - Delta score for candidate Giambullari is 1.5420881453251223
# - Delta score for candidate Vasari+ is 0.9923937497998981
# - Delta score for candidate Ghiberti is 1.7540051859748025
# - Delta score for candidate Minerbetti is 1.1820405054820156
# - Delta score for candidate Sanga is 1.141183834607809
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  20 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 1.00389662167732
# - Delta score for candidate Borghini is 1.3169248241219416
# - Delta score for candidate Giambullari is 1.3752216894616198
# - Delta score for candidate Vasari is 1.087054298340977
# - Delta score for candidate Ghiberti is 1.4752739637786716
# - Delta score for candidate Minerbetti is 1.294959478845898
# - Delta score for candidate Sanga is 1.400755759086273
#
#
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  30 ;
#
# - Delta score for candidate Bartoli is 0.847141567403517
# - Delta score for candidate Borghini is 1.0988984845472407
# - Delta score for candidate Giambullari is 1.1514797073026115
# - Delta score for candidate Vasari is 0.9013874175316071
# - Delta score for candidate Vcopy is 0.975330424705161
# - Delta score for candidate Ghiberti is 1.2679272018718453
# - Delta score for candidate Minerbetti is 1.099600778801403
# - Delta score for candidate Sanga is 1.165321688219972
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  30 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 1.001886759952234
# - Delta score for candidate Borghini is 1.3147820105932928
# - Delta score for candidate Giambullari is 1.3723224308982493
# - Delta score for candidate Vasari+ is 1.0884073588753995
# - Delta score for candidate Ghiberti is 1.4744841021584378
# - Delta score for candidate Minerbetti is 1.2928135110089913
# - Delta score for candidate Sanga is 1.3974169368398643
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  30 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9260450189791207
# - Delta score for candidate Borghini is 1.1952403790285389
# - Delta score for candidate Giambullari is 1.38475169981232
# - Delta score for candidate Vasari is 0.9994821725389459
# - Delta score for candidate Ghiberti is 1.436278931252373
# - Delta score for candidate Minerbetti is 1.2117193522561622
# - Delta score for candidate Sanga is 1.3053451609858333
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  40 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.8045702363101824
# - Delta score for candidate Borghini is 1.01107295295732
# - Delta score for candidate Giambullari is 1.1878061847806816
# - Delta score for candidate Vasari is 0.8730062071448405
# - Delta score for candidate Vcopy is 0.9605169460530247
# - Delta score for candidate Ghiberti is 1.209919483353101
# - Delta score for candidate Minerbetti is 0.9960483158387519
# - Delta score for candidate Sanga is 1.165429608028418
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  40 ; tokenizer: language = 'italian'
#
#
# - Delta score for candidate Bartoli is 0.9388039004977351
# - Delta score for candidate Borghini is 1.1967348690492483
# - Delta score for candidate Giambullari is 1.3854121348338952
# - Delta score for candidate Vasari+ is 1.0361422541204675
# - Delta score for candidate Ghiberti is 1.3918550244940346
# - Delta score for candidate Minerbetti is 1.1643271899086518
# - Delta score for candidate Sanga is 1.3680984265782343
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  40 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.9453792564025106
# - Delta score for candidate Borghini is 1.1760968404758225
# - Delta score for candidate Giambullari is 1.4738971872387776
# - Delta score for candidate Vasari is 0.9823461854012707
# - Delta score for candidate Ghiberti is 1.3157419530630223
# - Delta score for candidate Minerbetti is 1.2327828766118583
# - Delta score for candidate Sanga is 1.33853078675211
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  50 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.8230737840739308
# - Delta score for candidate Borghini is 1.0094566428677632
# - Delta score for candidate Giambullari is 1.285807286341826
# - Delta score for candidate Vasari is 0.8433615289080159
# - Delta score for candidate Vcopy is 0.920752378757996
# - Delta score for candidate Ghiberti is 1.1571260653645996
# - Delta score for candidate Minerbetti is 1.0772062229288126
# - Delta score for candidate Sanga is 1.157215845699238
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  50 ; tokenizer: language = 'italian'
#
# - Delta score for candidate Bartoli is 0.9439071643291492
# - Delta score for candidate Borghini is 1.1744184840012581
# - Delta score for candidate Giambullari is 1.4718425840606657
# - Delta score for candidate Vasari+ is 0.9860034535044467
# - Delta score for candidate Ghiberti is 1.314802710878829
# - Delta score for candidate Minerbetti is 1.2311510578779323
# - Delta score for candidate Sanga is 1.3361552214271908
#
# the nltk.FreqDist(whole_corpus).most_common(x) value was:  50 ; tokenizer: language = 'italian'

# %% [markdown]
# # feature zscores
#
# for Vasari+ 50
#
# dict_keys(['che', 'e', 'di', 'la', 'et', 'a', 'non', 'per', 'in', 'il', 'si', 'io', 'l', 'le', 'con', 'del', 'della', 'mi', 'è', 'se', 'da', 'al', 'vi', 'vostra', 'come', 'ho', 'questo', 'cosa', 'un', 'mio', 'sua', 'una', 'de', 'ma', 'perché', 'ha', 'gli', 'lo', 'o', 'più', 'alla', 'messer', 'molto', 'd', 'voi', 'el', 'i', 'ne', 'questa', 'signor'])
#
#
# for Vasari 50
#
# dict_keys(['che', 'e', 'di', 'et', 'la', 'a', 'non', 'per', 'in', 'il', 'si', 'io', 'l', 'le', 'della', 'del', 'con', 'mi', 'è', 'se', 'al', 'da', 'vostra', 'vi', 'come', 'ho', 'questo', 'cosa', 'mio', 'sua', 'un', 'ma', 'una', 'perché', 'de', 'gli', 'o', 'lo', 'ha', 'molto', 'el', 'messer', 'voi', 'signor', 'più', 'alla', 'ne', 'questa', 'd', 'sono'])

# %%
(feature_zscores['Vasari'].keys())
# Out:
# dict_keys(['che', 'e', 'di', 'et', 'la', 'a', 'non', 'per', 'in', 'il', 'si', 'io', 'l', 'le', 'della', 'del', 'con', 'mi', 'è', 'se', 'al', 'da', 'vostra', 'vi', 'come', 'ho', 'questo', 'cosa', 'mio', 'sua', 'un', 'ma', 'una', 'perché', 'de', 'gli', 'o', 'lo', 'ha', 'molto', 'el', 'messer', 'voi', 'signor', 'più', 'alla', 'ne', 'questa', 'd', 'sono'])

# %% [markdown]
# # results
# ## Get a frequency distribution
# whole_corpus_freq_dist = list(nltk.FreqDist(whole_corpus).most_common(40))
#
# ### .most_common(20)
#
# - Delta score for candidate Bartoli is 1.838567213310585
# - Delta score for candidate Borghini is 2.212588708509892
# - Delta score for candidate Giambullari is 2.3887643490055224
# - Delta score for candidate Vasari is 1.8931766640767909
# - Delta score for candidate Vcopy is 2.1447275267148367
#
#
# # .most_common(30)
#
# - Delta score for candidate Bartoli is 1.7577106697854776
# - Delta score for candidate Borghini is 2.1216984237448617
# - Delta score for candidate Giambullari is 2.134965208752774
# - Delta score for candidate Vasari is 1.931615052520559
# - Delta score for candidate Vcopy is 2.16038276179463
#
# the nltk.FreqDist(whole_corpus).most_common(X) value was:  30 ; tokenizer: language = 'italian'
#
#
#
# ### .most_common(40)
#
# - Delta score for candidate Bartoli is 1.5905160467937012
# - Delta score for candidate Borghini is 1.9350455324941702
# - Delta score for candidate Giambullari is 2.076301702793525
# - Delta score for candidate Vasari is 1.6893137604038295
# - Delta score for candidate Vcopy is 1.8748150015597838
#
#
#
# ### .most_common(50)
#
# - Delta score for candidate Bartoli is 1.4523928184962533
# - Delta score for candidate Borghini is 1.8047511042785178
# - Delta score for candidate Giambullari is 2.089697790842044
# - Delta score for candidate Vasari is 1.591271219282905
# - Delta score for candidate Vcopy is 1.7585336358282706
#
# ### .most_common(100)
# - Delta score for candidate Bartoli is 1.6547129258282405
# - Delta score for candidate Borghini is 1.7310287339170731
# - Delta score for candidate Giambullari is 2.061855363803096
# - Delta score for candidate Vasari is 1.5978447600399246
# - Delta score for candidate Vcopy is 1.7595221289137672
#
#
# ### .most_common(200)
#
# - Delta score for candidate Bartoli is 1.8559837207812162
# - Delta score for candidate Borghini is 1.9069649266433921
# - Delta score for candidate Giambullari is 2.1526371263687722
# - Delta score for candidate Vasari is 1.8195480012687923
# - Delta score for candidate Vcopy is 1.9867602944880658
#
#
# ### .most_common(500)
#
# - Delta score for candidate Bartoli is 1.6692189153794925
# - Delta score for candidate Borghini is 1.6751827120540324
# - Delta score for candidate Giambullari is 1.9896435201968878
# - Delta score for candidate Vasari is 1.5844653842381329
# - Delta score for candidate Vcopy is 1.7378617376750174
#
#
# ### .most_common(1000)
#
# - Delta score for candidate Bartoli is 1.561114152322625
# - Delta score for candidate Borghini is 1.5408040808889625
# - Delta score for candidate Giambullari is 1.8263234008450473
# - Delta score for candidate Vasari is 1.5367722383052635
# - Delta score for candidate Vcopy is 1.702135563650981
#
# the nltk.FreqDist(whole_corpus).most_common(X) value was:  1000
#
#
# ### .most_common(2000)
#
# - Delta score for candidate Bartoli is 1.447382305617218
# - Delta score for candidate Borghini is 1.3904418615732568
# - Delta score for candidate Giambullari is 1.6272694350761017
# - Delta score for candidate Vasari is 1.3756849118429249
# - Delta score for candidate Vcopy is 1.6250483882999922
#
# the nltk.FreqDist(whole_corpus).most_common(X) value was:  2000 ; tokenizer: language = 'italian'
#
#
# ### .most_common(5000)
#
# - Delta score for candidate Bartoli is 1.4238902538551055
# - Delta score for candidate Borghini is 1.3356429499408466
# - Delta score for candidate Giambullari is 1.3484106260054398
# - Delta score for candidate Vasari is 1.291135589191854
# - Delta score for candidate Vcopy is 1.515776438240675
#
# the nltk.FreqDist(whole_corpus).most_common(X) value was:  5000 ; tokenizer: language = 'italian'
#
# ### .most common(7500)
#
# - Delta score for candidate Bartoli is 1.3635809672705872
# - Delta score for candidate Borghini is 1.3716397949147685
# - Delta score for candidate Giambullari is 1.2429869755393799
# - Delta score for candidate Vasari is 1.2511525924497338
# - Delta score for candidate Vcopy is 1.4165442657836949
#
# the nltk.FreqDist(whole_corpus).most_common(X) value was:  7500 ; tokenizer: language = 'italian'
#
# ### .most common(10000)
#
# - Delta score for candidate Bartoli is 1.3574824743526004
# - Delta score for candidate Borghini is 1.218754065162964
# - Delta score for candidate Giambullari is 1.0584340638156833
# - Delta score for candidate Vasari is 1.134738413711443
# - Delta score for candidate Vcopy is 1.2635989500315485
#
# the nltk.FreqDist(whole_corpus).most_common(X) value was:  10000 ; tokenizer: language = 'italian'
