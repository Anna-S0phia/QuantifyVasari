# %%
import os
import nltk
import math
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
datapath = './data/Memofonte_letters/Vasari_letters_vite_Ghiberti/'
datapath_bio = './data/Datasets/Delta/'
new_path_R = './data/Datasets/R_1568/'
new_path_R0 = './data/Datasets/R_1550/'

# %%
fig = plt.figure(dpi = 150)

X = [20, 30, 40, 50, 70, 100] 

Borghini = [0.947, 1.1327,1.1032, 1.1178,1.1725, 1.1237  ]
Bartoli = [0.7078,0.8712, 0.8265,0.9037, 1.0659, 1.0691  ]
Giambullari = [1.1382, 1.2872,1.3676, 1.4525,1.4636 ,1.3544 ]
Vasari = [0.705,0.8943, 0.8003, 0.7559,0.7973,  0.853  ]
Minerbetti = [0.9967, 1.1809, 1.1788,1.1624, 1.2037, 1.2006 ]
Sanga = [0.8878,1.2924, 1.2948, 1.2585, 1.4306, 1.3967 ]
Ghiberti = [1.5337,1.3867,1.3634 ,1.3198, 1.3075, 1.3234  ]



# Bartoli
Y1 = Bartoli     #[0.9843033355131554,1.001886759952234,0.9388039004977351,0.9439071643291492]
plt.plot(X, Y1, label = "Bartoli") 

# Borghini
Y2 =  Borghini     #[1.2822332683581057,1.3147820105932928,1.1967348690492483,1.1744184840012581]
plt.plot(X, Y2, label = "Borghini") 

# Giambullari
Y3=  Giambullari               #[1.5420881453251223, 1.3723224308982493,1.3854121348338952,1.4718425840606657]
plt.plot(X, Y3, label = "Giambullari") 

# Vasari
Y4 =  Vasari              #  [0.9923937497998981, 1.0884073588753995, 1.0361422541204675, 0.9860034535044467]
plt.plot(X, Y4, label = "Vasari +", marker = "o") 

#Ghiberti
Y5 = Ghiberti                      #[1.7540051859748025,1.4744841021584378, 1.3918550244940346, 1.314802710878829 ]
plt.plot(X, Y5, label = "Ghiberti") 


# Minerbetti
Y6 =  Minerbetti             #[1.1820405054820156,1.2928135110089913, 1.1643271899086518, 1.2311510578779323 ]
plt.plot(X, Y6, label = "Minerbetti") 


# Sangaletti
Y7 =  Sanga                    #[1.141183834607809, 1.3974169368398643, 1.3680984265782343,1.3361552214271908]
plt.plot(X, Y7, label = "Sanga") 

  
# Labeling the X-axis 
plt.xlabel('number of most common words') 
# Labeling the Y-axis 
plt.ylabel('Delta score') 
# Give a title to the graph
plt.title('Delta score distribution for every authorship candidate\n') 

#plt.xlim([0,8000])
#plt.ylim([1.2, 2.0])
# Show a legend on the plot 
plt.legend(bbox_to_anchor=(1.1, 1.05)) 

plt.show()
#plt.rcParams["figure.figsize"] = (10,5)

#plt.figure.figsize(14,6)
